# %%
import pandas as pd
import os
import torch
from tqdm import tqdm
import numpy as np
import shutil
from TTS.api import TTS
from transformers import pipeline
import soundfile as sf
from librosa import resample
from subprocess import check_call
import random

# %%
import sys
print(sys.version)
# Out:
# 3.10.13 (main, Nov 21 2023, 14:24:09) [GCC 11.4.0]

# %%
df = pd.read_csv('TWATC_processed.csv')
df
# Out:
#      idx      type  character  \
# 0    NaN    speech    Madison
# 1    NaN  consigne        NaN
# 2    NaN    speech  Alexandre
# 3    NaN    speech    Madison
# 4    NaN    speech  Alexandre
# ..   ...       ...        ...
# 551  NaN  consigne        NaN
# 552  NaN    speech    Madison
# 553  NaN    speech  Alexandre
# 554  NaN  consigne        NaN
# 555  NaN    speech    Madison
#
#                                               sentence  \
# 0                                                  No!
# 1    Surprised, Alexandre jumps up and points his g...
# 2                            One move and you're dead!
# 3                                  Please don't shoot!
# 4                                            Hands up!
# ..                                                 ...
# 551  He looks towards the audience, towards the win...
# 552                So? should I tell her to come over?
# 553  She crossed the Atlantic to find me. I can cro...
# 554                          Alexander kisses Madison.
# 555  I'll let you go alone. You will see. Almost no...
#
#     j-hartmann/emotion-english-distilroberta-base  \
# 0                                           anger
# 1                                             NaN
# 2                                           anger
# 3                                            fear
# 4                                             joy
# ..                                            ...
# 551                                           NaN
# 552                                      surprise
# 553                                       neutral
# 554                                           NaN
# 555                                       neutral
#
#     SamLowe/roberta-base-go_emotion michellejieli/emotion_text_classifier
# 0                       disapproval                                 anger
# 1                               NaN                                   NaN
# 2                           neutral                                 anger
# 3                           neutral                                  fear
# 4                           neutral                                 anger
# ..                              ...                                   ...
# 551                             NaN                                   NaN
# 552                       curiosity                               neutral
# 553                         neutral                               neutral
# 554                             NaN                                   NaN
# 555                         neutral                               neutral
#
# [556 rows x 7 columns]

# %%
list_character = df['character'].dropna().unique().tolist()
list_character
# Out:
# ['Madison', 'Alexandre']

# %%
dico = {
    "Madison" : "bea",
    "Alexandre" : "sam",
}
emotion_dico = {
    "anger": "Angry",
    "disgust": "Disgusted",
    "neutral": "Neutral",
    "sadness": "Sleepy", 
    "joy": "Amused",
    "fear": "Neutral",
    "surprise": "Neutral",
}

# %%
df['audio'] = df['character'].map(dico)
df['emotion'] = df['michellejieli/emotion_text_classifier'].map(emotion_dico)
df
# Out:
#      idx      type  character  \
# 0    NaN    speech    Madison
# 1    NaN  consigne        NaN
# 2    NaN    speech  Alexandre
# 3    NaN    speech    Madison
# 4    NaN    speech  Alexandre
# ..   ...       ...        ...
# 551  NaN  consigne        NaN
# 552  NaN    speech    Madison
# 553  NaN    speech  Alexandre
# 554  NaN  consigne        NaN
# 555  NaN    speech    Madison
#
#                                               sentence  \
# 0                                                  No!
# 1    Surprised, Alexandre jumps up and points his g...
# 2                            One move and you're dead!
# 3                                  Please don't shoot!
# 4                                            Hands up!
# ..                                                 ...
# 551  He looks towards the audience, towards the win...
# 552                So? should I tell her to come over?
# 553  She crossed the Atlantic to find me. I can cro...
# 554                          Alexander kisses Madison.
# 555  I'll let you go alone. You will see. Almost no...
#
#     j-hartmann/emotion-english-distilroberta-base  \
# 0                                           anger
# 1                                             NaN
# 2                                           anger
# 3                                            fear
# 4                                             joy
# ..                                            ...
# 551                                           NaN
# 552                                      surprise
# 553                                       neutral
# 554                                           NaN
# 555                                       neutral
#
#     SamLowe/roberta-base-go_emotion michellejieli/emotion_text_classifier  \
# 0                       disapproval                                 anger
# 1                               NaN                                   NaN
# 2                           neutral                                 anger
# 3                           neutral                                  fear
# 4                           neutral                                 anger
# ..                              ...                                   ...
# 551                             NaN                                   NaN
# 552                       curiosity                               neutral
# 553                         neutral                               neutral
# 554                             NaN                                   NaN
# 555                         neutral                               neutral
#
#     audio  emotion
# 0     bea    Angry
# 1     NaN      NaN
# 2     sam    Angry
# 3     bea  Neutral
# 4     sam    Angry
# ..    ...      ...
# 551   NaN      NaN
# 552   bea  Neutral
# 553   sam  Neutral
# 554   NaN      NaN
# 555   bea  Neutral
#
# [556 rows x 9 columns]

# %%
# Drop non audio lines
df = df.dropna(subset=['audio'])
df
# Out:
#      idx    type  character  \
# 0    NaN  speech    Madison
# 2    NaN  speech  Alexandre
# 3    NaN  speech    Madison
# 4    NaN  speech  Alexandre
# 6    NaN  speech    Madison
# ..   ...     ...        ...
# 549  NaN  speech    Madison
# 550  NaN  speech  Alexandre
# 552  NaN  speech    Madison
# 553  NaN  speech  Alexandre
# 555  NaN  speech    Madison
#
#                                               sentence  \
# 0                                                  No!
# 2                            One move and you're dead!
# 3                                  Please don't shoot!
# 4                                            Hands up!
# 6    Calm down, you see, I'm unarmed . Now please p...
# ..                                                 ...
# 549  Yes, but she hasn't read it yet. She didn't kn...
# 550  I still love her. This book is the proof of that.
# 552                So? should I tell her to come over?
# 553  She crossed the Atlantic to find me. I can cro...
# 555  I'll let you go alone. You will see. Almost no...
#
#     j-hartmann/emotion-english-distilroberta-base  \
# 0                                           anger
# 2                                           anger
# 3                                            fear
# 4                                             joy
# 6                                            fear
# ..                                            ...
# 549                                      surprise
# 550                                           joy
# 552                                      surprise
# 553                                       neutral
# 555                                       neutral
#
#     SamLowe/roberta-base-go_emotion michellejieli/emotion_text_classifier  \
# 0                       disapproval                                 anger
# 2                           neutral                                 anger
# 3                           neutral                                  fear
# 4                           neutral                                 anger
# 6                           neutral                                  fear
# ..                              ...                                   ...
# 549                         neutral                               sadness
# 550                            love                                   joy
# 552                       curiosity                               neutral
# 553                         neutral                               neutral
# 555                         neutral                               neutral
#
#     audio  emotion
# 0     bea    Angry
# 2     sam    Angry
# 3     bea  Neutral
# 4     sam    Angry
# 6     bea  Neutral
# ..    ...      ...
# 549   bea   Sleepy
# 550   sam   Amused
# 552   bea  Neutral
# 553   sam  Neutral
# 555   bea  Neutral
#
# [509 rows x 9 columns]

# %%
df[df["emotion"].isna()]
# Out:
# Empty DataFrame
# Columns: [idx, type, character, sentence, j-hartmann/emotion-english-distilroberta-base, SamLowe/roberta-base-go_emotion, michellejieli/emotion_text_classifier, audio, emotion]
# Index: []

# %%
# Create a new column 'count_column' using a loop
counts = {}
count_column = []

for value in df['character']:
    if value in counts:
        counts[value] += 1
    else:
        counts[value] = 1
    count_column.append(counts[value])

df['count_column'] = count_column
# Out:
# /tmp/ipykernel_138082/1039323909.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['count_column'] = count_column

# %%
folder_path = 'test_dataset'
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# %%
def get_fname(s):
    return s.split("\t")[0]

def get_emotion(s):
    return get_fname(s).split("_")[0].split("/")[1].lower()
def get_spker_id(s):
    return get_fname(s).split("_")[0].split("/")[0].lower()

def get_utt_id(s):
    return get_fname(s).split(".")[0].split("_")[-1]
def get_all_different_utt_id(tsv_lines) -> list:
    utts_per_speaker = {
    "sam": [],
    "bea": [],
    "josh": [],
    "jenie": [],
    }
    for line in tsv_lines:
        spkr = get_spker_id(line)
        utt_id = get_utt_id(line)
        if utt_id not in utts_per_speaker[spkr]:
            utts_per_speaker[spkr].append(utt_id)
    return utts_per_speaker
def tsv_per_emotion(tsv_lines, emotion) -> list:
    lines = []
    for line in tsv_lines:
        if emotion.lower() == get_emotion(line):      
            lines.append(line)      
    return lines
def get_tsv_lines_for_utt_ids(tsv_lines, specific_utt_id):
    utts_per_speaker = []
    for line in tsv_lines:
        spkr = get_spker_id(line)
        utt_id = get_utt_id(line)
        if utt_id == specific_utt_id:
            # Assuming the audio file name is also part of the line, extract it
            utts_per_speaker.append(line)

    return utts_per_speaker
def get_tsv_lines_for_emotion(tsv_lines, emotion):
    audio_files_name = []

    for line in tsv_lines:
        if emotion == get_emotion(line):
            # Assuming the audio file name is also part of the line, extract it
            audio_files_name.append(line)

    return audio_files_name


tsv_lines = open("data.tsv", "r").readlines()
root, tsv_lines = tsv_lines[0], tsv_lines[1:]
utts = get_all_different_utt_id(tsv_lines)

# %%
def get_number_audio_per_emotion(df, emotion):
    return len(df[df['emotion'] == emotion])

# %%
# Function to randomly sample and remove rows from DataFrame
def sample_and_remove_rows(df, num_rows):
    # Randomly sample rows
    sampled_rows = df.sample(n=num_rows)

    # Remove sampled rows from the original DataFrame
    df.drop(sampled_rows.index, inplace=True)

    return sampled_rows, df

# %%
def decompose_base_2(number):
    powers = []
    remainder = number
    power = 0

    # Find the highest power of 2 less than or equal to the number
    while 2 ** power <= number:
        power += 1

    # Subtract powers of 2 from the number and store them
    for i in range(power - 1, -1, -1):
        if 2 ** i <= remainder:
            powers.append(2 ** i)
            remainder -= 2 ** i

    return powers

# %%
def call(
    model_dir,
    data,
    split,
    output_path,
    src_emotion,
    trg_emotion,
    dict,
    user_dir,
    dataset
):
    cmd = f"""python3 fairseq/examples/emotion_conversion/preprocessing.py \
    --model-dir {model_dir} \
    --data {data} \
    --split {split} \
    --output-path {output_path} \
    --src-emotion {src_emotion} \
    --trg-emotion {trg_emotion} \
    --dict {dict} \
    --user-dir {user_dir} \
    --dataset {dataset}"""
    
    check_call(cmd, shell=True)

# %%
file_path = "fairseq/examples/emotion_conversion/data"

# %%
import torch
device = "cuda" if torch.cuda.is_available() else "cpu"

# %%
tts = TTS("tts_models/en/ljspeech/fast_pitch").to(device)
# Out:
#  > tts_models/en/ljspeech/fast_pitch is already downloaded.
#  > vocoder_models/en/ljspeech/hifigan_v2 is already downloaded.
#  > Using model: fast_pitch
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
#  > Vocoder Model: hifigan
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > log_func:np.log
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:20
#  | > fft_size:1024
#  | > power:1.5
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:0
#  | > mel_fmax:8000.0
#  | > pitch_fmin:1.0
#  | > pitch_fmax:640.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:4.0
#  | > clip_norm:True
#  | > do_trim_silence:False
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > do_amp_to_db_linear:True
#  | > do_amp_to_db_mel:True
#  | > do_rms_norm:False
#  | > db_level:None
#  | > stats_path:None
#  | > base:2.718281828459045
#  | > hop_length:256
#  | > win_length:1024
#  > Generator Model: hifigan_generator
#  > Discriminator Model: hifigan_discriminator
# Removing weight norm...

# %%
root = "/home/utilisateur/createch/project/emotion/dataset"

# %%
num_audios = len(os.listdir("/home/utilisateur/createch/project/emotion/dataset_final"))

# %%
print(get_all_different_utt_id(tsv_lines))
# Out:
# {'sam': ['0150', '0100', '0201', '0306', '0036', '0312', '0423', '0399', '0501', '0390', '0151', '0309', '0438', '0101', '0200', '0037', '0313', '0405', '0422', '0356', '0398', '0391', '0224', '0355', '0369', '0388', '0503', '0373', '0392', '0152', '0219', '0102', '0148', '0203', '0034', '0310', '0421', '0336', '0354', '0368', '0389', '0420', '0502', '0372', '0153', '0218', '0103', '0149', '0202', '0305', '0035', '0311', '0407', '0349', '0375', '0222', '0331', '0353', '0248', '0302', '0032', '0316', '0400', '0427', '0154', '0252', '0104', '0348', '0374', '0168', '0223', '0330', '0352', '0504', '0204', '0249', '0303', '0033', '0426', '0155', '0029', '0105', '0300', '0030', '0314', '0402', '0425', '0250', '0418', '0106', '0329', '0377', '0199', '0220', '0333', '0351', '0206', '0301', '0031', '0315', '0403', '0424', '0157', '0251', '0419', '0107', '0328', '0376', '0198', '0221', '0350', '0411', '0436', '0145', '0243', '0162', '0358', '0396', '0342', '0215', '0364', '0410', '0437', '0144', '0242', '0308', '0038', '0163', '0359', '0365', '0384', '0397', '0321', '0343', '0160', '0366', '0387', '0394', '0322', '0340', '0140', '0413', '0434', '0147', '0241', '0161', '0367', '0386', '0395', '0323', '0341', '0217', '0412', '0435', '0146', '0408', '0324', '0346', '0166', '0381', '0141', '0319', '0428', '0111', '0210', '0361', '0415', '0432', '0325', '0347', '0167', '0380', '0393', '0246', '0429', '0110', '0211', '0360', '0414', '0433', '0143', '0208', '0245', '0212', '0363', '0417', '0430', '0109', '0326', '0378', '0164', '0383', '0142', '0209', '0244', '0112', '0158', '0213', '0362', '0431', '0108', '0327', '0345', '0379', '0197', '0382', '0124', '0009', '0045', '0067', '0013', '0225', '0255', '0086', '0119', '0272', '0171', '0190', '0268', '0450', '0487', '0125', '0008', '0281', '0044', '0066', '0012', '0254', '0118', '0273', '0170', '0191', '0269', '0451', '0486', '0169', '0188', '0270', '0058', '0173', '0452', '0485', '0126', '0282', '0047', '0475', '0065', '0084', '0011', '0227', '0257', '0298', '0448', '0189', '0271', '0449', '0059', '0193', '0453', '0127', '0283', '0046', '0474', '0064', '0010', '0299', '0085', '0175', '0194', '0454', '0483', '0276', '0478', '0499', '0017', '0469', '0079', '0120', '0284', '0041', '0473', '0063', '0082', '0098', '0174', '0195', '0455', '0482', '0277', '0479', '0016', '0468', '0078', '0121', '0285', '0040', '0472', '0062', '0083', '0099', '0138', '0015', '0253', '0122', '0239', '0286', '0043', '0061', '0080', '0028', '0177', '0196', '0456', '0481', '0274', '0338', '0139', '0014', '0123', '0238', '0287', '0042', '0470', '0060', '0081', '0176', '0457', '0480', '0275', '0339', '0006', '0230', '0093', '0131', '0295', '0050', '0445', '0462', '0089', '0116', '0185', '0492', '0021', '0267', '0488', '0007', '0231', '0069', '0092', '0130', '0294', '0051', '0444', '0463', '0073', '0088', '0184', '0020', '0266', '0489', '0114', '0187', '0490', '0057', '0023', '0265', '0129', '0232', '0048', '0091', '0133', '0228', '0258', '0297', '0052', '0460', '0070', '0115', '0491', '0022', '0264', '0128', '0005', '0233', '0049', '0132', '0229', '0259', '0296', '0053', '0446', '0461', '0025', '0181', '0279', '0477', '0496', '0135', '0018', '0291', '0054', '0441', '0466', '0076', '0002', '0234', '0097', '0024', '0262', '0113', '0180', '0278', '0497', '0134', '0019', '0290', '0440', '0467', '0003', '0235', '0096', '0137', '0293', '0056', '0464', '0074', '0236', '0289', '0095', '0027', '0178', '0261', '0280', '0459', '0183', '0494', '0136', '0292', '0442', '0465', '0075', '0001', '0237', '0288', '0094', '0026', '0260', '0458', '0182', '0004', '0214', '0240', '0165', '0159', '0332', '0055', '0077', '0371', '0335', '0357', '0404', '0087', '0439', '0247', '0370', '0334', '0500', '0307', '0071', '0304', '0406', '0072', '0068', '0318', '0156', '0416', '0320', '0385', '0205', '0409', '0090', '0207', '0498', '0186', '0471', '0117', '0476', '0179', '0039', '0484', '0263', '0337', '0226', '0172', '0443', '0495', '0192', '0493', '0447', ...

# %%
emotion_include = df["emotion"].unique()
emotion_include = emotion_include[~pd.isnull(emotion_include)]
print(emotion_include)
emotion_include = [emotion for emotion in emotion_include.tolist() if emotion != "Neutral"]
utts = get_all_different_utt_id(tsv_lines)
dataset_path = "/home/utilisateur/createch/project/emotion/dataset_test"
        
#clear the Neutral folder
for emov_charac in dico.values():
    if os.path.exists(os.path.join(dataset_path, emov_charac, "Neutral")):
        shutil.rmtree(os.path.join(dataset_path, emov_charac, "Neutral"))
    os.makedirs(os.path.join(dataset_path, emov_charac, "Neutral"), exist_ok=True)
print(tsv_lines)
emotion_df = df[df['emotion'].isin(emotion_include)]
plus_df = df[df["emotion"] == "Neutral"].sample(n = int(len(emotion_df)/2))
emotion_df = pd.concat([emotion_df, plus_df])
lines = []
for index, row in emotion_df.iterrows():
    
    #Create the wav name
    character = row["character"]

    specific_utt = utts[dico[character]].pop()
    name_audio = f"{character}_{row['count_column']}_{specific_utt}.wav"
    audio_path = os.path.join(dataset_path, f"{dico[character]}/Neutral",name_audio)
    print(audio_path)
    
    #Creation of the audio file
    sentence = row['sentence']
    print(sentence)
    tts.tts_to_file(sentence, file_path=audio_path)
    
    #Resample the audio file
    data, samplerate = sf.read(audio_path)
    data = resample(data,orig_sr = samplerate, target_sr = 16000)
    sf.write(audio_path, data, 16000)
    name = os.path.join(f"{dico[character]}/Neutral",name_audio)
    line = f"{name}\t{len(data)}\t\n"
    lines.append(line)

    for emotion in emotion_include:
        #save the line for the tsv
        tsv_lines_emotion = tsv_per_emotion(tsv_lines, emotion)
        tsv_lines_utt = get_tsv_lines_for_utt_ids(tsv_lines_emotion,specific_utt)
        for x in tsv_lines_utt:
            if x[-2:]!="\n" and x[:3]=="sam":
                x+="\n"
        print(tsv_lines_utt)
    
        #copy the audio of the tsv
        for line in tsv_lines_utt:
            if get_spker_id(line) == dico[character]:
                lines += [line]
                os.makedirs(os.path.join(dataset_path, dico[character], emotion), exist_ok=True)
                shutil.copy(os.path.join(root, line.split("\t")[0]), os.path.join(dataset_path, line.split("\t")[0]))
    
#save the tsv
lines = [dataset_path + "\t\n"] + lines
print(lines)
lines = lines[:-1] + [lines[-1][:-1]]
open(os.path.join(file_path, "data.tsv"), "w").writelines(lines)
for emotion in emotion_include:
    call(
        model_dir="/home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/save ",
        data="/home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/data",
        split="data",
        output_path="/home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/processed_data_test",
        src_emotion="neutral",
        trg_emotion=emotion.lower(),
        dict="/home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/data/dict.txt",
        user_dir="/home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/fairseq_models",
        dataset=f"/home/utilisateur/createch/project/emotion/dataset_final/{emotion.lower()}"
    )
        
    #save the good tsv
# Out:
# ['Angry' 'Neutral' 'Amused' 'Sleepy' 'Disgusted']
# ['sam/Disgusted/Disgust_141-168_0150.wav\t75293\n', 'sam/Disgusted/Disgust_85-112_0100.wav\t60026\n', 'sam/Disgusted/Disgust_197-224_0201.wav\t115258\n', 'sam/Disgusted/disgust_281-308_0306.wav\t91293\n', 'sam/Disgusted/Disgust_29-56_0036.wav\t86106\n', 'sam/Disgusted/disgust_309-336_0312.wav\t119915\n', 'sam/Disgusted/disgust_421-448_0423.wav\t116247\n', 'sam/Disgusted/disgust_393-420_0399.wav\t63877\n', 'sam/Disgusted/disgust_477-504_0501.wav\t104297\n', 'sam/Disgusted/disgust_367-392_0390.wav\t74930\n', 'sam/Disgusted/Disgust_141-168_0151.wav\t119778\n', 'sam/Disgusted/disgust_309-336_0309.wav\t72949\n', 'sam/Disgusted/disgust_421-448_0438.wav\t136852\n', 'sam/Disgusted/Disgust_85-112_0101.wav\t68491\n', 'sam/Disgusted/Disgust_197-224_0200.wav\t127790\n', 'sam/Disgusted/Disgust_29-56_0037.wav\t88157\n', 'sam/Disgusted/disgust_309-336_0313.wav\t100057\n', 'sam/Disgusted/disgust_393-420_0405.wav\t108974\n', 'sam/Disgusted/disgust_421-448_0422.wav\t153259\n', 'sam/Disgusted/disgust_336-364_0356.wav\t121221\n', 'sam/Disgusted/disgust_393-420_0398.wav\t160582\n', 'sam/Disgusted/disgust_367-392_0391.wav\t90512\n', 'sam/Disgusted/Disgust_197-224_0224.wav\t105151\n', 'sam/Disgusted/disgust_336-364_0355.wav\t107924\n', 'sam/Disgusted/disgust_367-392_0369.wav\t119377\n', 'sam/Disgusted/disgust_367-392_0388.wav\t61380\n', 'sam/Disgusted/disgust_477-504_0503.wav\t127044\n', 'sam/Disgusted/disgust_367-392_0373.wav\t97931\n', 'sam/Disgusted/disgust_367-392_0392.wav\t109922\n', 'sam/Disgusted/Disgust_141-168_0152.wav\t102751\n', 'sam/Disgusted/Disgust_197-224_0219.wav\t99963\n', 'sam/Disgusted/Disgust_85-112_0102.wav\t56903\n', 'sam/Disgusted/Disgust_141-168_0148.wav\t110532\n', 'sam/Disgusted/Disgust_197-224_0203.wav\t76311\n', 'sam/Disgusted/Disgust_29-56_0034.wav\t85752\n', 'sam/Disgusted/disgust_309-336_0310.wav\t119915\n', 'sam/Disgusted/disgust_421-448_0421.wav\t98524\n', 'sam/Disgusted/disgust_309-336_0336.wav\t100646\n', 'sam/Disgusted/disgust_336-364_0354.wav\t89269\n', 'sam/Disgusted/disgust_367-392_0368.wav\t106821\n', 'sam/Disgusted/disgust_367-392_0389.wav\t46984\n', 'sam/Disgusted/disgust_393-420_0420.wav\t114750\n', 'sam/Disgusted/disgust_477-504_0502.wav\t124567\n', 'sam/Disgusted/disgust_367-392_0372.wav\t124604\n', 'sam/Disgusted/Disgust_141-168_0153.wav\t120916\n', 'sam/Disgusted/Disgust_197-224_0218.wav\t89864\n', 'sam/Disgusted/Disgust_85-112_0103.wav\t81476\n', 'sam/Disgusted/Disgust_141-168_0149.wav\t115961\n', 'sam/Disgusted/Disgust_197-224_0202.wav\t146559\n', 'sam/Disgusted/disgust_281-308_0305.wav\t146704\n', 'sam/Disgusted/Disgust_29-56_0035.wav\t112154\n', 'sam/Disgusted/disgust_309-336_0311.wav\t99801\n', 'sam/Disgusted/disgust_393-420_0407.wav\t183206\n', 'sam/Disgusted/disgust_336-364_0349.wav\t117634\n', 'sam/Disgusted/disgust_367-392_0375.wav\t163102\n', 'sam/Disgusted/Disgust_197-224_0222.wav\t92904\n', 'sam/Disgusted/disgust_309-336_0331.wav\t97931\n', 'sam/Disgusted/disgust_336-364_0353.wav\t110972\n', 'sam/Disgusted/Disgust_225-252_0248.wav\t96447\n', 'sam/Disgusted/disgust_281-308_0302.wav\t140797\n', 'sam/Disgusted/Disgust_29-56_0032.wav\t107005\n', 'sam/Disgusted/disgust_309-336_0316.wav\t109024\n', 'sam/Disgusted/disgust_393-420_0400.wav\t96368\n', 'sam/Disgusted/disgust_421-448_0427.wav\t99510\n', 'sam/Disgusted/Disgust_141-168_0154.wav\t120009\n', 'sam/Disgusted/Disgust_225-252_0252.wav\t107118\n', 'sam/Disgusted/Disgust_85-112_0104.wav\t113452\n', 'sam/Disgusted/disgust_336-364_0348.wav\t85170\n', 'sam/Disgusted/disgust_367-392_0374.wav\t92626\n', 'sam/Disgusted/Disgust_141-168_0168.wav\t109651\n', 'sam/Disgusted/Disgust_197-224_0223.wav\t74773\n', 'sam/Disgusted/disgust_309-336_0330.wav\t82248\n', 'sam/Disgusted/disgust_336-364_0352.wav\t81136\n', 'sam/Disgusted/disgust_477-504_0504.wav\t82341\n', 'sam/Disgusted/Disgust_197-224_0204.wav\t106116\n', 'sam/Disgusted/Disgust_225-252_0249.wav\t135706\n', 'sam/Disgusted/disgust_281-308_0303.wav\t103321\n', 'sam/Disgusted/Disgust_29-56_0033.wav\t1152 ...
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_1_0421.wav
# No!
#  > Text splitted to sentences.
# ['No!']
#  > Processing time: 0.10388565063476562
#  > Real-time factor: 0.10277631893828885
# ['sam/Angry/anger_421-448_0421.wav\t65871\n', 'jenie/Angry/anger_421-448_0421.wav\t66238\n']
# ['sam/Amused/amused_421-448_0421.wav\t69176\n']
# ['sam/Sleepy/sleepiness_421-448_0421.wav\t85895\n', 'jenie/Sleepy/sleepiness_421-448_0421.wav\t72437\n', 'bea/Sleepy/sleepiness_421-448_0421.wav\t59237\n']
# ['sam/Disgusted/disgust_421-448_0421.wav\t98524\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_1_0317.wav
# One move and you're dead!
#  > Text splitted to sentences.
# ["One move and you're dead!"]
#  > Processing time: 0.08425688743591309
#  > Real-time factor: 0.040756940329104145
# ['bea/Angry/anger_309-336_0317.wav\t34617\n', 'jenie/Angry/anger_309-336_0317.wav\t67096\n', 'sam/Angry/anger_309-336_0317.wav\t36701\n']
# ['sam/Amused/amused_309-336_0317.wav\t66777\n', 'jenie/Amused/amused_309-336_0317.wav\t66520\n']
# ['sam/Sleepy/sleepiness_309-336_0317.wav\t66962\n', 'bea/Sleepy/sleepiness_309-336_0317.wav\t53766\n', 'jenie/Sleepy/sleepiness_309-336_0317.wav\t49227\n']
# ['bea/Disgusted/disgust_309-336_0317.wav\t44936\n', 'sam/Disgusted/disgust_309-336_0317.wav\t58959\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_2_0256.wav
# Hands up!
#  > Text splitted to sentences.
# ['Hands up!']
#  > Processing time: 0.10108661651611328
#  > Real-time factor: 0.08530924273500834
# ['sam/Angry/anger_253-280_0256.wav\t65845\n', 'bea/Angry/anger_253-280_0256.wav\t53967\n', 'jenie/Angry/anger_253-280_0256.wav\t70894\n']
# ['sam/Amused/amused_253-280_0256.wav\t106119\n', 'josh/Amused/amused_252-280_0256.wav\t59730\n']
# ['bea/Sleepy/sleepiness_253-280_0256.wav\t102276\n', 'jenie/Sleepy/sleepiness_253-280_0256.wav\t64370\n', 'josh/Sleepy/sleepiness_253_280_0256.wav\t85029\n']
# ['bea/Disgusted/disgust_253-280_0256.wav\t89487\n', 'jenie/Disgusted/disgust_253-280_0256.wav\t88495\n', 'sam/Disgusted/disgust_253-280_0256.wav\t105181\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_6_0344.wav
# What do you want? To rob me? There is nothing of value here, believe me.
#  > Text splitted to sentences.
# ['What do you want?', 'To rob me?', 'There is nothing of value here, believe me.']
#  > Processing time: 0.25463128089904785
#  > Real-time factor: 0.041133950766498686
# ['sam/Angry/anger_336-364_0344.wav\t56131\n', 'jenie/Angry/anger_337-364_0344.wav\t65025\n']
# ['sam/Amused/amused_336-364_0344.wav\t100803\n']
# ['sam/Sleepy/sleepiness_336-364_0344.wav\t105172\n', 'bea/Sleepy/sleepiness_337-364_0344.wav\t90471\n', 'jenie/Sleepy/sleepiness_337-360_0344.wav\t91189\n']
# []
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_10_0402.wav
# I lost my cat. Haven't you seen her, by any chance. Or even picked her up in your house. If she also entered without being invited.
#  > Text splitted to sentences.
# ['I lost my cat.', "Haven't you seen her, by any chance.", 'Or even picked her up in your house.', 'If she also entered without being invited.']
#  > Processing time: 0.37281322479248047
#  > Real-time factor: 0.034970271264438954
# ['sam/Angry/anger_393-420_0402.wav\t69396\n', 'jenie/Angry/anger_393-420_0402.wav\t98290\n']
# ['sam/Amused/amused_393-420_0402.wav\t156427\n']
# ['sam/Sleepy/sleepiness_393-420_0402.wav\t136136\n', 'jenie/Sleepy/sleepiness_393-420_0402.wav\t109107\n', 'bea/Sleepy/sleepiness_393-420_0402.wav\t101123\n']
# ['sam/Disgusted/disgust_393-420_0402.wav\t132387\n', 'jenie/Disgusted/disgust_393-420_0402.wav\t111211\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_12_0437.wav
# Tofu! Tofu!
#  > Text splitted to sentences.
# ['Tofu!', 'Tofu!']
#  > Processing time: 0.18314194679260254
#  > Real-time factor: 0.07298799751982515
# ['sam/Angry/anger_421-448_0437.wav\t73372\n', 'jenie/Angry/anger_421-448_0437.wav\t123527\n']
# ['sam/Amused/amused_421-448_0437.wav\t161851\n']
# ['sam/Sleepy/sleepiness_421-448_0437.wav\t114115\n', 'jenie/Sleepy/sleepiness_421-448_0437.wav\t88001\n', 'bea/Sleepy/sleepiness_421-448_0437.wav\t136639\n']
# ['sam/Disgusted/disgust_421-448_0437.wav\t136861\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_15_0436.wav
# Of course it's serious! If I can't find her quickly, he's going to die. She's an indoor cat, you see, she's not meant to live outside in the wilderness.
#  > Text splitted to sentences.
# ["Of course it's serious!", "If I can't find her quickly, he's going to die.", "She's an indoor cat, you see, she's not meant to live outside in the wilderness."]
#  > Processing time: 0.2754228115081787
#  > Real-time factor: 0.02550339730630308
# ['sam/Angry/anger_421-448_0436.wav\t67731\n', 'jenie/Angry/anger_421-448_0436.wav\t88986\n']
# ['sam/Amused/amused_421-448_0436.wav\t117341\n']
# ['sam/Sleepy/sleepiness_421-448_0436.wav\t103031\n', 'jenie/Sleepy/sleepiness_421-448_0436.wav\t88185\n', 'bea/Sleepy/sleepiness_421-448_0436.wav\t103013\n']
# ['sam/Disgusted/disgust_421-448_0436.wav\t93894\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_17_0411.wav
# Kibbles! Vegetable-based kibbles, like me.
#  > Text splitted to sentences.
# ['Kibbles!', 'Vegetable-based kibbles, like me.']
#  > Processing time: 0.20139408111572266
#  > Real-time factor: 0.054356877798199234
# ['sam/Angry/anger_393-420_0411.wav\t75962\n', 'jenie/Angry/anger_393-420_0411.wav\t112615\n']
# ['sam/Amused/amused_393-420_0411.wav\t133269\n']
# ['sam/Sleepy/sleepiness_393-420_0411.wav\t148497\n', 'jenie/Sleepy/sleepiness_393-420_0411.wav\t94772\n', 'bea/Sleepy/sleepiness_393-420_0411.wav\t115243\n']
# ['sam/Disgusted/disgust_393-420_0411.wav\t115225\n', 'jenie/Disgusted/disgust_393-420_0411.wav\t96159\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_19_0216.wav
# And I suppose not eating meat is its personal choice, of course?
#  > Text splitted to sentences.
# ['And I suppose not eating meat is its personal choice, of course?']
#  > Processing time: 0.10664105415344238
#  > Real-time factor: 0.0235482619380248
# ['sam/Angry/anger_197-224_0216.wav\t62540\n', 'bea/Angry/anger_197-224_0216.wav\t72648\n', 'jenie/Angry/anger_197-224_0216.wav\t102672\n']
# ['sam/Amused/amused_197-224_0216.wav\t114165\n', 'bea/Amused/amused_196-224_0216.wav\t76411\n', 'josh/Amused/amused_197-224_0216.wav\t69134\n']
# ['sam/Sleepy/sleepiness_197-224_0216.wav\t87153\n', 'bea/Sleepy/sleepiness_197-224_0216.wav\t112195\n', 'jenie/Sleepy/sleepiness_197-224_0216.wav\t83751\n', 'josh/Sleepy/sleepiness_197-224_0216.wav\t84857\n']
# ['bea/Disgusted/disgust_197-224_0216.wav\t89074\n', 'sam/Disgusted/Disgust_197-224_0216.wav\t108157\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_21_0412.wav
# I don't know. Anyway, I'm against animals in circuses.
#  > Text splitted to sentences.
# ["I don't know.", "Anyway, I'm against animals in circuses."]
#  > Processing time: 0.1864457130432129
#  > Real-time factor: 0.040035135289448076
# ['sam/Angry/anger_393-420_0412.wav\t69117\n', 'jenie/Angry/anger_393-420_0412.wav\t76600\n']
# ['sam/Amused/amused_393-420_0412.wav\t74847\n']
# ['sam/Sleepy/sleepiness_393-420_0412.wav\t128953\n', 'jenie/Sleepy/sleepiness_393-420_0412.wav\t62324\n', 'bea/Sleepy/sleepiness_393-420_0412.wav\t94974\n']
# ['sam/Disgusted/disgust_393-420_0412.wav\t97572\n', 'jenie/Disgusted/disgust_393-420_0412.wav\t62734\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_22_0401.wav
# No, I hate the concept of pets. And the concept of domestication in general, for that matter.  I myself have remained wild.
#  > Text splitted to sentences.
# ['No, I hate the concept of pets.', 'And the concept of domestication in general, for that matter.', 'I myself have remained wild.']
#  > Processing time: 0.2936286926269531
#  > Real-time factor: 0.030427629297429863
# ['sam/Angry/anger_393-420_0401.wav\t83162\n', 'jenie/Angry/anger_393-420_0401.wav\t99462\n']
# ['sam/Amused/amused_393-420_0401.wav\t144113\n']
# ['sam/Sleepy/sleepiness_393-420_0401.wav\t141654\n', 'bea/Sleepy/sleepiness_393-420_0401.wav\t130973\n', 'jenie/Sleepy/sleepiness_393-420_0401.wav\t88350\n']
# ['jenie/Disgusted/disgust_393-420_0401.wav\t92074\n', 'sam/Disgusted/disgust_393-420_0401.wav\t148188\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_23_0447.wav
# No, I haven't seen your vegan cat. And if you allow me, I think this absurd conversation has lasted long enough.
#  > Text splitted to sentences.
# ["No, I haven't seen your vegan cat.", 'And if you allow me, I think this absurd conversation has lasted long enough.']
#  > Processing time: 0.19567203521728516
#  > Real-time factor: 0.023436513430716243
# ['sam/Angry/anger_421-448_0447.wav\t62834\n', 'jenie/Angry/anger_421-448_0447.wav\t80567\n']
# ['sam/Amused/amused_421-448_0447.wav\t88643\n']
# ['sam/Sleepy/sleepiness_421-448_0447.wav\t81786\n', 'bea/Sleepy/sleepiness_421-448_0447.wav\t87240\n', 'jenie/Sleepy/sleepiness_421-448_0447.wav\t60274\n']
# ['sam/Disgusted/disgust_421-448_0447.wav\t97875\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_24_0414.wav
# Be quiet!
#  > Text splitted to sentences.
# ['Be quiet!']
#  > Processing time: 0.08436322212219238
#  > Real-time factor: 0.06260800510885642
# ['sam/Angry/anger_393-420_0414.wav\t47563\n', 'jenie/Angry/anger_393-420_0414.wav\t76690\n']
# ['sam/Amused/amused_393-420_0414.wav\t97461\n']
# ['sam/Sleepy/sleepiness_393-420_0414.wav\t125324\n', 'jenie/Sleepy/sleepiness_393-420_0414.wav\t67508\n', 'bea/Sleepy/sleepiness_393-420_0414.wav\t89927\n']
# ['sam/Disgusted/disgust_393-420_0414.wav\t95803\n', 'jenie/Disgusted/disgust_393-420_0414.wav\t51926\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_24_0493.wav
# I beg your pardon?
#  > Text splitted to sentences.
# ['I beg your pardon?']
#  > Processing time: 0.0834202766418457
#  > Real-time factor: 0.05093645048606274
# ['jenie/Angry/anger_477-504_0493.wav\t80568\n']
# ['sam/Amused/amused_477-504_0493.wav\t113651\n']
# ['sam/Sleepy/sleepiness_477-504_0493.wav\t97774\n', 'bea/Sleepy/sleepiness_477-504_0493.wav\t100359\n', 'jenie/Sleepy/sleepiness_477-504_0493.wav\t116405\n']
# []
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_28_0449.wav
# But. I feel bad leaving you like this.
#  > Text splitted to sentences.
# ['But.', 'I feel bad leaving you like this.']
#  > Processing time: 0.18435096740722656
#  > Real-time factor: 0.04975688933765846
# ['jenie/Angry/anger_449-476_0449.wav\t97503\n']
# ['jenie/Amused/amused_449-476_0449.wav\t86235\n', 'sam/Amused/amused_449-476_0449.wav\t124383\n']
# ['sam/Sleepy/sleepiness_449-476_0449.wav\t115647\n', 'jenie/Sleepy/sleepiness_449-476_0449.wav\t85590\n', 'bea/Sleepy/sleepiness_449-476_0449.wav\t109858\n']
# ['sam/Disgusted/disgust_449-476_0449.wav\t155496\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_31_0455.wav
# You had a gun at your head.
#  > Text splitted to sentences.
# ['You had a gun at your head.']
#  > Processing time: 0.08414888381958008
#  > Real-time factor: 0.03959292608871929
# ['jenie/Angry/anger_449-476_0455.wav\t100695\n']
# ['sam/Amused/amused_449-476_0455.wav\t127088\n', 'jenie/Amused/amused_449-476_0455.wav\t102609\n']
# ['sam/Sleepy/sleepiness_449-476_0455.wav\t115648\n', 'jenie/Sleepy/sleepiness_449-476_0455.wav\t87573\n', 'bea/Sleepy/sleepiness_449-476_0455.wav\t114538\n']
# ['sam/Disgusted/disgust_449-476_0455.wav\t149556\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_33_0192.wav
# We had sex without a condom, we rode motorcycles without helmets, and ingested all sorts of prohibited substances, the exact composition of which, believe me, no one knew. Fifty years later, the few old folks like me who survived that blessed era parade in the streets because they are afraid of getting vaccinated. And you expect me not to be depressed?
#  > Text splitted to sentences.
# ['We had sex without a condom, we rode motorcycles without helmets, and ingested all sorts of prohibited substances, the exact composition of which, believe me, no one knew.', 'Fifty years later, the few old folks like me who survived that blessed era parade in the streets because they are afraid of getting vaccinated.', 'And you expect me not to be depressed?']
#  > Processing time: 0.3433864116668701
#  > Real-time factor: 0.014966614965002227
# ['jenie/Angry/anger_169-196_0192.wav\t65141\n', 'sam/Angry/anger_169-196_0192.wav\t27187\n']
# ['sam/Amused/amused_169-196_0192.wav\t65694\n', 'bea/Amused/amused_169-196_0192.wav\t35921\n', 'josh/Amused/amused_169-196_0192.wav\t37375\n']
# ['sam/Sleepy/sleepiness_169_196_0192.wav\t57003\n', 'bea/Sleepy/sleepiness_169-196_0192.wav\t77868\n', 'jenie/Sleepy/sleepiness_169-196_0192.wav\t47628\n', 'josh/Sleepy/sleepiness_169-196_0192.wav\t53154\n']
# ['bea/Disgusted/disgust_169-196_0192.wav\t51259\n', 'sam/Disgusted/Disgust_169_196_0192.wav\t63075\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_37_0495.wav
# Today, young people don't want to change the world, they just want to save the planet. And it's not looking good.
#  > Text splitted to sentences.
# ["Today, young people don't want to change the world, they just want to save the planet.", "And it's not looking good."]
#  > Processing time: 0.21317028999328613
#  > Real-time factor: 0.028155578483515187
# ['sam/Angry/anger_477-504_0495.wav\t53626\n', 'jenie/Angry/anger_477-504_0495.wav\t73128\n']
# ['sam/Amused/amused_477-504_0495.wav\t96505\n']
# ['bea/Sleepy/sleepiness_477-504_0495.wav\t104371\n', 'jenie/Sleepy/sleepiness_477-504_0495.wav\t107901\n']
# []
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_38_0443.wav
# No, but at least we will have had a lot of fun.
#  > Text splitted to sentences.
# ['No, but at least we will have had a lot of fun.']
#  > Processing time: 0.10489106178283691
#  > Real-time factor: 0.035009201869574263
# ['sam/Angry/anger_421-448_0443.wav\t49603\n', 'jenie/Angry/anger_421-448_0443.wav\t75757\n']
# ['sam/Amused/amused_421-448_0443.wav\t91388\n']
# ['sam/Sleepy/sleepiness_421-448_0443.wav\t62029\n', 'bea/Sleepy/sleepiness_421-448_0443.wav\t77546\n', 'jenie/Sleepy/sleepiness_421-448_0443.wav\t56230\n']
# ['sam/Disgusted/disgust_421-448_0443.wav\t83225\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_39_0473.wav
# You don't seem to be laughing much anymore.
#  > Text splitted to sentences.
# ["You don't seem to be laughing much anymore."]
#  > Processing time: 0.10416245460510254
#  > Real-time factor: 0.03372066778310005
# ['jenie/Angry/anger_449-476_0473.wav\t85317\n']
# ['sam/Amused/amused_449-476_0473.wav\t98199\n', 'jenie/Amused/amused_449-476_0473.wav\t73443\n']
# ['sam/Sleepy/sleepiness_449-476_0473.wav\t75440\n', 'jenie/Sleepy/sleepiness_449-476_0473.wav\t61480\n', 'bea/Sleepy/sleepiness_449-476_0473.wav\t84025\n']
# ['sam/Disgusted/disgust_449-476_0473.wav\t71473\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_40_0172.wav
# And do you seriously think you can save the planet. by feeding that poor carnivore who didn't ask for anything with vegetable kibbles?
#  > Text splitted to sentences.
# ['And do you seriously think you can save the planet.', "by feeding that poor carnivore who didn't ask for anything with vegetable kibbles?"]
#  > Processing time: 0.21080923080444336
#  > Real-time factor: 0.02373153661185864
# ['sam/Angry/anger_169-196_0172.wav\t64812\n', 'jenie/Angry/anger_169-196_0172.wav\t81185\n']
# ['sam/Amused/amused_169-196_0172.wav\t116557\n', 'josh/Amused/amused_169-196_0172.wav\t54983\n', 'bea/Amused/amused_169-196_0172.wav\t70953\n']
# ['sam/Sleepy/sleepiness_169_196_0172.wav\t113563\n', 'bea/Sleepy/sleepiness_169-196_0172.wav\t87944\n', 'jenie/Sleepy/sleepiness_169-196_0172.wav\t70902\n']
# ['jenie/Disgusted/disgust_169-190_0172.wav\t71955\n', 'sam/Disgusted/Disgust_169_196_0172.wav\t107005\n', 'bea/Disgusted/disgust_169-196_0172.wav\t100799\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_41_0226.wav
# Anyway, I envy all those from my generation who died before the age of thirty. Can you imagine Jimi Hendrix and Janis Joplin in a retirement home, discussing the potential dangers of a vaccine between rounds of Scrabble. I'd rather die than see that.
#  > Text splitted to sentences.
# ['Anyway, I envy all those from my generation who died before the age of thirty.', 'Can you imagine Jimi Hendrix and Janis Joplin in a retirement home, discussing the potential dangers of a vaccine between rounds of Scrabble.', "I'd rather die than see that."]
#  > Processing time: 0.31104493141174316
#  > Real-time factor: 0.01768175539750891
# ['sam/Angry/anger_225_252_0226.wav\t50733\n', 'bea/Angry/anger_225-252_0226.wav\t56043\n', 'jenie/Angry/anger_225-252_0226.wav\t63921\n']
# ['sam/Amused/amused_225-252_0226.wav\t105688\n', 'bea/Amused/amused_225-252_0226.wav\t50286\n', 'jenie/Amused/amused_225-252_0226.wav\t77503\n']
# ['sam/Sleepy/sleepiness_225-252_0226.wav\t98689\n', 'bea/Sleepy/sleepiness_225-252_0226.wav\t67854\n', 'jenie/Sleepy/sleepiness_225-252_0226.wav\t82943\n', 'josh/Sleepy/sleepiness_225-252_0226.wav\t62709\n']
# ['bea/Disgusted/disgust_225-252_0226.wav\t52102\n', 'sam/Disgusted/Disgust_225-252_0226.wav\t85709\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_43_0337.wav
# That's none of your business. I don't even know why I'm talking about all this with you, I don't know you. And by the way, why are you still here?
#  > Text splitted to sentences.
# ["That's none of your business.", "I don't even know why I'm talking about all this with you, I don't know you.", 'And by the way, why are you still here?']
#  > Processing time: 0.31609368324279785
#  > Real-time factor: 0.03283459766480597
# ['sam/Angry/anger_336-364_0337.wav\t63963\n', 'jenie/Angry/anger_337-364_0337.wav\t102279\n']
# ['sam/Amused/amused_336-364_0337.wav\t111980\n']
# ['bea/Sleepy/sleepiness_337-364_0337.wav\t115243\n', 'jenie/Sleepy/sleepiness_337-360_0337.wav\t97348\n', 'sam/Sleepy/sleepiness_336-364_0337.wav\t107483\n']
# ['sam/Disgusted/disgust_336-364_0337.wav\t123912\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_46_0263.wav
# I'm sorry for receiving you like this. I'm not used to having visitors anymore.
#  > Text splitted to sentences.
# ["I'm sorry for receiving you like this.", "I'm not used to having visitors anymore."]
#  > Processing time: 0.2070753574371338
#  > Real-time factor: 0.03383634419825113
# ['sam/Angry/anger_253-280_0263.wav\t63042\n', 'bea/Angry/anger_253-280_0263.wav\t52477\n', 'jenie/Angry/anger_253-280_0263.wav\t89489\n']
# ['sam/Amused/amused_253-280_0263.wav\t92246\n', 'bea/Amused/amused_253-280_0263.wav\t58724\n', 'josh/Amused/amused_252-280_0263.wav\t66732\n']
# ['sam/Sleepy/sleepiness_253-280_0263.wav\t109455\n', 'bea/Sleepy/sleepiness_253-280_0263.wav\t102513\n', 'jenie/Sleepy/sleepiness_253-280_0263.wav\t70442\n', 'josh/Sleepy/sleepiness_253_280_0263.wav\t95658\n']
# ['bea/Disgusted/disgust_253-280_0263.wav\t73730\n', 'jenie/Disgusted/disgust_253-280_0263.wav\t63302\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_49_0484.wav
# No. And when I see the world today, I'm glad I don't have any.
#  > Text splitted to sentences.
# ['No.', "And when I see the world today, I'm glad I don't have any."]
#  > Processing time: 0.18820858001708984
#  > Real-time factor: 0.03822206739405422
# ['sam/Angry/anger_477-504_0484.wav\t38449\n', 'jenie/Angry/anger_477-504_0484.wav\t40885\n']
# ['sam/Amused/amused_477-504_0484.wav\t51469\n']
# ['sam/Sleepy/sleepiness_477-504_0484.wav\t37848\n', 'bea/Sleepy/sleepiness_477-504_0484.wav\t57040\n']
# ['sam/Disgusted/disgust_477-504_0484.wav\t51605\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_52_0499.wav
# At the same time. is it by stopping having children that we will save humanity?
#  > Text splitted to sentences.
# ['At the same time.', 'is it by stopping having children that we will save humanity?']
#  > Processing time: 0.2441089153289795
#  > Real-time factor: 0.04170748809047234
# ['sam/Angry/anger_477-504_0499.wav\t50986\n', 'jenie/Angry/anger_477-504_0499.wav\t70737\n']
# ['sam/Amused/amused_477-504_0499.wav\t101570\n']
# ['sam/Sleepy/sleepiness_477-504_0499.wav\t63271\n', 'jenie/Sleepy/sleepiness_477-504_0499.wav\t91835\n', 'bea/Sleepy/sleepiness_477-504_0499.wav\t91548\n']
# ['sam/Disgusted/disgust_477-504_0499.wav\t92765\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_64_0462.wav
# Spy on you? Not at all! I am a great admirer of your work. When I arrived in Paris, I tried to reach out to you. But your agent told me that you didn't want to see anyone.
#  > Text splitted to sentences.
# ['Spy on you?', 'Not at all!', 'I am a great admirer of your work.', 'When I arrived in Paris, I tried to reach out to you.', "But your agent told me that you didn't want to see anyone."]
#  > Processing time: 0.5297036170959473
#  > Real-time factor: 0.03952557243545143
# ['jenie/Angry/anger_449-476_0462.wav\t104257\n']
# ['sam/Amused/amused_449-476_0462.wav\t112733\n', 'jenie/Amused/amused_449-476_0462.wav\t85660\n']
# ['sam/Sleepy/sleepiness_449-476_0462.wav\t111090\n', 'jenie/Sleepy/sleepiness_449-476_0462.wav\t66980\n', 'bea/Sleepy/sleepiness_449-476_0462.wav\t97392\n']
# ['sam/Disgusted/disgust_449-476_0462.wav\t93539\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_64_0039.wav
# You are completely insane! I'm warning you, if you don't leave me alone, I'll file a harassment complaint. And what do you expect from me, anyway? Are you a journalist?
#  > Text splitted to sentences.
# ['You are completely insane!', "I'm warning you, if you don't leave me alone, I'll file a harassment complaint.", 'And what do you expect from me, anyway?', 'Are you a journalist?']
#  > Processing time: 0.3600502014160156
#  > Real-time factor: 0.030486248699093547
# ['sam/Angry/anger_29-56_0039.wav\t60768\n', 'bea/Angry/anger_29-56_0039.wav\t64910\n', 'jenie/Angry/anger_29-56_0039.wav\t66875\n']
# ['sam/Amused/amused_29-56_0039.wav\t76416\n', 'bea/Amused/amused_29-45_0039.wav\t70192\n', 'jenie/Amused/amused_29-56_0039.wav\t63419\n']
# ['sam/Sleepy/sleepiness_29-56_0039.wav\t95778\n', 'bea/Sleepy/sleepiness_29-56_0039.wav\t90479\n', 'jenie/Sleepy/sleepiness_29-56_0039.wav\t64696\n', 'josh/Sleepy/sleepiness_29-56_0039.wav\t63545\n']
# ['bea/Disgusted/disgust_29-56_0039.wav\t77158\n', 'sam/Disgusted/Disgust_29-56_0039.wav\t109350\n', 'jenie/Disgusted/disgust_29-56_0039.wav\t77983\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_71_0460.wav
# It's this novel that convinced me to come and study in Paris. I consider it as your best book.
#  > Text splitted to sentences.
# ["It's this novel that convinced me to come and study in Paris.", 'I consider it as your best book.']
#  > Processing time: 0.19135832786560059
#  > Real-time factor: 0.027788798270788284
# ['jenie/Angry/anger_449-476_0460.wav\t89917\n']
# ['sam/Amused/amused_449-476_0460.wav\t63691\n', 'jenie/Amused/amused_449-476_0460.wav\t53487\n']
# ['sam/Sleepy/sleepiness_449-476_0460.wav\t74897\n', 'jenie/Sleepy/sleepiness_449-476_0460.wav\t52712\n', 'bea/Sleepy/sleepiness_449-476_0460.wav\t80778\n']
# ['sam/Disgusted/disgust_449-476_0460.wav\t105152\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_72_0179.wav
# I don't write anything at all. It is a legend maintained by my publisher so that I am not completely forgotten, and my old books continue to 10 sell a bit. Anyway, I will not give any interview. Not to you or anyone else.  approaches her with a threatening look.) Now get out!
#  > Text splitted to sentences.
# ["I don't write anything at all.", 'It is a legend maintained by my publisher so that I am not completely forgotten, and my old books continue to 10 sell a bit.', 'Anyway, I will not give any interview.', 'Not to you or anyone else.', 'approaches her with a threatening look.', ') Now get out!']
#  > Processing time: 0.5528564453125
#  > Real-time factor: 0.028170719836437513
# ['sam/Angry/anger_169-196_0179.wav\t58346\n', 'jenie/Angry/anger_169-196_0179.wav\t104032\n']
# ['sam/Amused/amused_169-196_0179.wav\t122238\n', 'bea/Amused/amused_169-196_0179.wav\t63477\n', 'josh/Amused/amused_169-196_0179.wav\t56204\n']
# ['sam/Sleepy/sleepiness_169_196_0179.wav\t91694\n', 'bea/Sleepy/sleepiness_169-196_0179.wav\t116892\n', 'jenie/Sleepy/sleepiness_169-196_0179.wav\t66679\n', 'josh/Sleepy/sleepiness_169-196_0179.wav\t71998\n']
# ['bea/Disgusted/disgust_169-196_0179.wav\t84248\n', 'jenie/Disgusted/disgust_169-190_0179.wav\t70948\n', 'sam/Disgusted/Disgust_169_196_0179.wav\t102436\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_74_0367.wav
# No!
#  > Text splitted to sentences.
# ['No!']
#  > Processing time: 0.08357882499694824
#  > Real-time factor: 0.08268633754409138
# ['sam/Angry/anger_367-392_0367.wav\t58289\n']
# ['sam/Amused/amused_367-392_0367.wav\t107470\n']
# ['sam/Sleepy/sleepiness_367-392_0367.wav\t98507\n', 'jenie/Sleepy/sleepiness_365-392_0367.wav\t73535\n', 'bea/Sleepy/sleepiness_365-392_0367.wav\t101462\n']
# ['sam/Disgusted/disgust_367-392_0367.wav\t102928\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_75_0365.wav
# I won't let you commit suicide before granting me this interview. I could have swum across the Atlantic to get it!
#  > Text splitted to sentences.
# ["I won't let you commit suicide before granting me this interview.", 'I could have swum across the Atlantic to get it!']
#  > Processing time: 0.17116284370422363
#  > Real-time factor: 0.02209891268314439
# ['sam/Angry/anger_367-392_0365.wav\t48400\n']
# ['sam/Amused/amused_367-392_0365.wav\t83821\n']
# ['sam/Sleepy/sleepiness_367-392_0365.wav\t100477\n', 'jenie/Sleepy/sleepiness_365-392_0365.wav\t84492\n', 'bea/Sleepy/sleepiness_365-392_0365.wav\t57083\n']
# ['sam/Disgusted/disgust_367-392_0365.wav\t92934\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_75_0476.wav
# It's the second time you've fainted in front of me. You read too many romance novels, miss. Nowadays, besides in plays, women don't faint like that at any moment just because they're contradicted.
#  > Text splitted to sentences.
# ["It's the second time you've fainted in front of me.", 'You read too many romance novels, miss.', "Nowadays, besides in plays, women don't faint like that at any moment just because they're contradicted."]
#  > Processing time: 0.3034183979034424
#  > Real-time factor: 0.022781175680233263
# ['jenie/Angry/anger_449-476_0476.wav\t87782\n']
# ['sam/Amused/amused_449-476_0476.wav\t107382\n', 'jenie/Amused/amused_449-476_0476.wav\t90601\n']
# ['bea/Sleepy/sleepiness_449-476_0476.wav\t91548\n', 'jenie/Sleepy/sleepiness_449-476_0476.wav\t78612\n', 'sam/Sleepy/sleepiness_449-476_0476.wav\t85159\n']
# ['sam/Disgusted/disgust_449-476_0476.wav\t83739\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_81_0117.wav
# I have a feeling that you are going to suggest that I get a cat. Do you want to get rid of yours, is that it? 11
#  > Text splitted to sentences.
# ['I have a feeling that you are going to suggest that I get a cat.', 'Do you want to get rid of yours, is that it?', '11']
#  > Processing time: 0.27882885932922363
#  > Real-time factor: 0.03218536073063794
# ['sam/Angry/anger_113-140_0117.wav\t73996\n', 'jenie/Angry/anger_113-140_0117.wav\t91814\n']
# ['sam/Amused/amused_113-140_0117.wav\t132358\n', 'jenie/Amused/amused_113-136_0117.wav\t76411\n', 'josh/Amused/amused_113-140_0117.wav\t101290\n', 'bea/Amused/amused_113-140_0117.wav\t82480\n']
# ['bea/Sleepy/sleepiness_113-140_0117.wav\t92301\n', 'jenie/Sleepy/sleepiness_113-140_0117.wav\t99847\n', 'josh/Sleepy/sleepiness_113_140_0117.wav\t82904\n', 'sam/Sleepy/sleepiness_113-140_0117.wav\t117870\n']
# ['bea/Disgusted/disgust_113-140_0117.wav\t103096\n', 'sam/Disgusted/Disgust_113-140_0117.wav\t108744\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_84_0471.wav
# That's exactly why I stopped writing.
#  > Text splitted to sentences.
# ["That's exactly why I stopped writing."]
#  > Processing time: 0.10341334342956543
#  > Real-time factor: 0.03519795354751046
# ['jenie/Angry/anger_449-476_0471.wav\t109127\n']
# ['sam/Amused/amused_449-476_0471.wav\t102319\n', 'jenie/Amused/amused_449-476_0471.wav\t110976\n']
# ['sam/Sleepy/sleepiness_449-476_0471.wav\t115869\n', 'bea/Sleepy/sleepiness_449-476_0471.wav\t109755\n', 'jenie/Sleepy/sleepiness_449-476_0471.wav\t102717\n']
# ['sam/Disgusted/disgust_449-476_0471.wav\t121933\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_85_0186.wav
# I'm not asking you to believe me. I'm asking you to leave me alone.
#  > Text splitted to sentences.
# ["I'm not asking you to believe me. I'm asking you to leave me alone."]
#  > Processing time: 0.10726022720336914
#  > Real-time factor: 0.021432216995018575
# ['sam/Angry/anger_169-196_0186.wav\t62997\n', 'jenie/Angry/anger_169-196_0186.wav\t108624\n']
# ['sam/Amused/amused_169-196_0186.wav\t151599\n', 'bea/Amused/amused_169-196_0186.wav\t76411\n', 'josh/Amused/amused_169-196_0186.wav\t67461\n']
# ['bea/Sleepy/sleepiness_169-196_0186.wav\t131986\n', 'jenie/Sleepy/sleepiness_169-196_0186.wav\t91684\n', 'josh/Sleepy/sleepiness_169-196_0186.wav\t95600\n', 'sam/Sleepy/sleepiness_169_196_0186.wav\t117624\n']
# ['bea/Disgusted/disgust_169-196_0186.wav\t128958\n', 'sam/Disgusted/Disgust_169_196_0186.wav\t118427\n', 'jenie/Disgusted/disgust_169-190_0186.wav\t94480\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_86_0498.wav
# I have nothing left to say. Worse yet, I have no one left to talk to. And there are days when I don't even feel like talking to myself.
#  > Text splitted to sentences.
# ['I have nothing left to say.', 'Worse yet, I have no one left to talk to.', "And there are days when I don't even feel like talking to myself."]
#  > Processing time: 0.2768239974975586
#  > Real-time factor: 0.027881171640087916
# ['sam/Angry/anger_477-504_0498.wav\t36148\n', 'jenie/Angry/anger_477-504_0498.wav\t52760\n']
# ['sam/Amused/amused_477-504_0498.wav\t91143\n']
# ['sam/Sleepy/sleepiness_477-504_0498.wav\t74930\n', 'bea/Sleepy/sleepiness_477-504_0498.wav\t80455\n', 'jenie/Sleepy/sleepiness_477-504_0498.wav\t72329\n']
# ['sam/Disgusted/disgust_477-504_0498.wav\t78623\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_87_0364.wav
# That's sad.
#  > Text splitted to sentences.
# ["That's sad."]
#  > Processing time: 0.08379983901977539
#  > Real-time factor: 0.06218990476528161
# ['sam/Angry/anger_336-364_0364.wav\t58289\n', 'jenie/Angry/anger_337-364_0364.wav\t101111\n']
# ['sam/Amused/amused_336-364_0364.wav\t121166\n']
# ['sam/Sleepy/sleepiness_336-364_0364.wav\t102597\n', 'bea/Sleepy/sleepiness_337-364_0364.wav\t86163\n']
# ['sam/Disgusted/disgust_336-364_0364.wav\t127139\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_87_0207.wav
# That's life. And in one way or another, mine is coming to an end.
#  > Text splitted to sentences.
# ["That's life.", 'And in one way or another, mine is coming to an end.']
#  > Processing time: 0.18595075607299805
#  > Real-time factor: 0.0337810948738598
# ['sam/Angry/anger_197-224_0207.wav\t40996\n', 'jenie/Angry/anger_197-224_0207.wav\t51676\n', 'bea/Angry/anger_197-224_0207.wav\t28022\n']
# ['sam/Amused/amused_197-224_0207.wav\t46011\n', 'bea/Amused/amused_196-224_0207.wav\t27290\n', 'josh/Amused/amused_197-224_0207.wav\t58924\n']
# ['bea/Sleepy/sleepiness_197-224_0207.wav\t83364\n', 'jenie/Sleepy/sleepiness_197-224_0207.wav\t42656\n', 'josh/Sleepy/sleepiness_197-224_0207.wav\t61199\n', 'sam/Sleepy/sleepiness_197-224_0207.wav\t57040\n']
# ['bea/Disgusted/disgust_197-224_0207.wav\t42272\n', 'sam/Disgusted/Disgust_197-224_0207.wav\t67343\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_90_0356.wav
# Yes. But it could end soon.
#  > Text splitted to sentences.
# ['Yes.', 'But it could end soon.']
#  > Processing time: 0.20136594772338867
#  > Real-time factor: 0.07104645332982464
# ['sam/Angry/anger_336-364_0356.wav\t45336\n', 'jenie/Angry/anger_337-364_0356.wav\t75543\n']
# ['sam/Amused/amused_336-364_0356.wav\t75225\n']
# ['sam/Sleepy/sleepiness_336-364_0356.wav\t93604\n', 'jenie/Sleepy/sleepiness_337-360_0356.wav\t81890\n', 'bea/Sleepy/sleepiness_337-364_0356.wav\t84779\n']
# ['sam/Disgusted/disgust_336-364_0356.wav\t121221\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_93_0090.wav
# Don't tell me you made up this story to force me not to upset you. and thus to accept this interview.
#  > Text splitted to sentences.
# ["Don't tell me you made up this story to force me not to upset you.", 'and thus to accept this interview.']
#  > Processing time: 0.19245147705078125
#  > Real-time factor: 0.027348132791359857
# ['sam/Angry/anger_85-112_0090.wav\t47076\n', 'bea/Angry/anger_85-112_0090.wav\t60583\n']
# ['sam/Amused/amused_85-112_0090.wav\t75065\n', 'bea/Amused/amused_85-112_0090.wav\t49023\n', 'jenie/Amused/amused_85-94_0090.wav\t52060\n', 'josh/Amused/amused_85-112_0090.wav\t71681\n']
# ['sam/Sleepy/sleepiness_85-112_0090.wav\t112964\n', 'bea/Sleepy/sleepiness_85-112_0090.wav\t66997\n', 'josh/Sleepy/sleepiness_85-112_0090.wav\t71828\n']
# ['bea/Disgusted/disgust_85-112_0090.wav\t69712\n', 'jenie/Disgusted/disgust_85-112_0090.wav\t62531\n', 'sam/Disgusted/Disgust_85-112_0090.wav\t75808\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_94_0355.wav
# Unfortunately, no.
#  > Text splitted to sentences.
# ['Unfortunately, no.']
#  > Processing time: 0.10168910026550293
#  > Real-time factor: 0.0521161365947922
# ['jenie/Angry/anger_337-364_0355.wav\t77867\n', 'sam/Angry/anger_336-364_0355.wav\t41431\n']
# ['sam/Amused/amused_336-364_0355.wav\t106417\n']
# ['sam/Sleepy/sleepiness_336-364_0355.wav\t79146\n', 'jenie/Sleepy/sleepiness_337-360_0355.wav\t65676\n', 'bea/Sleepy/sleepiness_337-364_0355.wav\t63545\n']
# ['sam/Disgusted/disgust_336-364_0355.wav\t107924\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_94_0409.wav
# I'm sorry for you.
#  > Text splitted to sentences.
# ["I'm sorry for you."]
#  > Processing time: 0.10073995590209961
#  > Real-time factor: 0.048458028526206294
# ['sam/Angry/anger_393-420_0409.wav\t53972\n', 'jenie/Angry/anger_393-420_0409.wav\t77938\n']
# ['sam/Amused/amused_393-420_0409.wav\t93621\n']
# ['sam/Sleepy/sleepiness_393-420_0409.wav\t123242\n', 'bea/Sleepy/sleepiness_393-420_0409.wav\t84246\n', 'jenie/Sleepy/sleepiness_393-420_0409.wav\t73687\n']
# ['jenie/Disgusted/disgust_393-420_0409.wav\t62288\n', 'sam/Disgusted/disgust_393-420_0409.wav\t82762\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_95_0205.wav
# No, but what an irony. I'm old, I don't have any desires left, I'm considering ending it. You're young, you have your whole life ahead of you, and it's your heart that betrays you.
#  > Text splitted to sentences.
# ['No, but what an irony.', "I'm old, I don't have any desires left, I'm considering ending it.", "You're young, you have your whole life ahead of you, and it's your heart that betrays you."]
#  > Processing time: 0.2999610900878906
#  > Real-time factor: 0.02423259729628784
# ['bea/Angry/anger_197-224_0205.wav\t45665\n', 'jenie/Angry/anger_197-224_0205.wav\t67408\n', 'sam/Angry/anger_197-224_0205.wav\t53293\n']
# ['sam/Amused/amused_197-224_0205.wav\t70423\n', 'bea/Amused/amused_196-224_0205.wav\t37114\n', 'josh/Amused/amused_197-224_0205.wav\t54815\n']
# ['sam/Sleepy/sleepiness_197-224_0205.wav\t63188\n', 'jenie/Sleepy/sleepiness_197-224_0205.wav\t78371\n', 'josh/Sleepy/sleepiness_197-224_0205.wav\t48379\n', 'bea/Sleepy/sleepiness_197-224_0205.wav\t66874\n']
# ['bea/Disgusted/disgust_197-224_0205.wav\t55052\n', 'sam/Disgusted/Disgust_197-224_0205.wav\t69778\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_97_0178.wav
# I tell myself that the remaining months of my life might be the most beautiful ones in my existence.
#  > Text splitted to sentences.
# ['I tell myself that the remaining months of my life might be the most beautiful ones in my existence.']
#  > Processing time: 0.1152338981628418
#  > Real-time factor: 0.017140498208922435
# ['sam/Angry/anger_169-196_0178.wav\t75560\n', 'jenie/Angry/anger_169-196_0178.wav\t120868\n']
# ['sam/Amused/amused_169-196_0178.wav\t134484\n', 'bea/Amused/amused_169-196_0178.wav\t85705\n', 'josh/Amused/amused_169-196_0178.wav\t63835\n']
# ['sam/Sleepy/sleepiness_169_196_0178.wav\t140640\n', 'jenie/Sleepy/sleepiness_169-196_0178.wav\t107590\n', 'josh/Sleepy/sleepiness_169-196_0178.wav\t95588\n', 'bea/Sleepy/sleepiness_169-196_0178.wav\t155765\n']
# ['sam/Disgusted/Disgust_169_196_0178.wav\t137094\n', 'bea/Disgusted/disgust_169-196_0178.wav\t111764\n', 'jenie/Disgusted/disgust_169-190_0178.wav\t87377\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_97_0385.wav
# Your joy of life depresses me. Do you ever doubt?
#  > Text splitted to sentences.
# ['Your joy of life depresses me.', 'Do you ever doubt?']
#  > Processing time: 0.16788911819458008
#  > Real-time factor: 0.04037909092703415
# ['sam/Angry/anger_367-392_0385.wav\t32383\n', 'jenie/Angry/anger_369-392_0385.wav\t54623\n']
# ['sam/Amused/amused_367-392_0385.wav\t53735\n']
# ['sam/Sleepy/sleepiness_367-392_0385.wav\t58119\n', 'bea/Sleepy/sleepiness_365-392_0385.wav\t58160\n', 'jenie/Sleepy/sleepiness_365-392_0385.wav\t50136\n']
# ['sam/Disgusted/disgust_367-392_0385.wav\t57959\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_98_0320.wav
# And there is really no hope?
#  > Text splitted to sentences.
# ['And there is really no hope?']
#  > Processing time: 0.08470320701599121
#  > Real-time factor: 0.040517739385252646
# ['sam/Angry/anger_309-336_0320.wav\t69519\n', 'bea/Angry/anger_309-336_0320.wav\t63131\n', 'jenie/Angry/anger_309-336_0320.wav\t110408\n']
# ['sam/Amused/amused_309-336_0320.wav\t111644\n', 'jenie/Amused/amused_309-336_0320.wav\t83731\n']
# ['sam/Sleepy/sleepiness_309-336_0320.wav\t93803\n', 'bea/Sleepy/sleepiness_309-336_0320.wav\t103030\n', 'jenie/Sleepy/sleepiness_309-336_0320.wav\t80953\n']
# ['bea/Disgusted/disgust_309-336_0320.wav\t104992\n', 'sam/Disgusted/disgust_309-336_0320.wav\t132009\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_99_0416.wav
# I could offer you my heart, I no longer have any use for it. I commit suicide, and I donate my organs to you.
#  > Text splitted to sentences.
# ['I could offer you my heart, I no longer have any use for it.', 'I commit suicide, and I donate my organs to you.']
#  > Processing time: 0.19127798080444336
#  > Real-time factor: 0.024223944798394
# ['sam/Angry/anger_393-420_0416.wav\t79935\n', 'jenie/Angry/anger_393-420_0416.wav\t91225\n']
# ['sam/Amused/amused_393-420_0416.wav\t130020\n']
# ['sam/Sleepy/sleepiness_393-420_0416.wav\t122633\n', 'bea/Sleepy/sleepiness_393-420_0416.wav\t130575\n', 'jenie/Sleepy/sleepiness_393-420_0416.wav\t87955\n']
# ['jenie/Disgusted/disgust_393-420_0416.wav\t90389\n', 'sam/Disgusted/disgust_393-420_0416.wav\t134237\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_103_0255.wav
# But that's terrible.
#  > Text splitted to sentences.
# ["But that's terrible."]
#  > Processing time: 0.084320068359375
#  > Real-time factor: 0.04594843582750639
# ['sam/Angry/anger_253-280_0255.wav\t70163\n', 'jenie/Angry/anger_253-280_0255.wav\t87165\n', 'bea/Angry/anger_253-280_0255.wav\t49816\n']
# ['sam/Amused/amused_253-280_0255.wav\t95415\n', 'bea/Amused/amused_253-280_0255.wav\t54566\n', 'josh/Amused/amused_252-280_0255.wav\t69238\n']
# ['sam/Sleepy/sleepiness_253-280_0255.wav\t77192\n', 'jenie/Sleepy/sleepiness_253-280_0255.wav\t71041\n', 'josh/Sleepy/sleepiness_253_280_0255.wav\t85027\n', 'bea/Sleepy/sleepiness_253-280_0255.wav\t92729\n']
# ['sam/Disgusted/disgust_253-280_0255.wav\t117304\n', 'bea/Disgusted/disgust_253-280_0255.wav\t69798\n', 'jenie/Disgusted/disgust_253-280_0255.wav\t72989\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_108_0116.wav
# Will you be cruel enough to let me go without fulfilling my dream?
#  > Text splitted to sentences.
# ['Will you be cruel enough to let me go without fulfilling my dream?']
#  > Processing time: 0.08592557907104492
#  > Real-time factor: 0.018877122374826045
# ['sam/Angry/anger_113-140_0116.wav\t75150\n', 'jenie/Angry/anger_113-140_0116.wav\t80759\n', 'bea/Angry/anger_113-140_0116.wav\t70249\n']
# ['sam/Amused/amused_113-140_0116.wav\t97352\n', 'bea/Amused/amused_113-140_0116.wav\t77991\n', 'jenie/Amused/amused_113-136_0116.wav\t88419\n', 'josh/Amused/amused_113-140_0116.wav\t60611\n']
# ['sam/Sleepy/sleepiness_113-140_0116.wav\t158187\n', 'josh/Sleepy/sleepiness_113_140_0116.wav\t80845\n', 'bea/Sleepy/sleepiness_113-140_0116.wav\t101177\n', 'jenie/Sleepy/sleepiness_113-140_0116.wav\t90467\n']
# ['sam/Disgusted/Disgust_113-140_0116.wav\t105274\n', 'bea/Disgusted/disgust_113-140_0116.wav\t103379\n']
# /home/utilisateur/createch/project/emotion/dataset_test/bea/Neutral/Madison_112_0224.wav
# Sorry, I don't have it with me.
#  > Text splitted to sentences.
# ["Sorry, I don't have it with me."]
#  > Processing time: 0.10248994827270508
#  > Real-time factor: 0.041432666460346636
# ['sam/Angry/anger_197-224_0224.wav\t72148\n', 'jenie/Angry/anger_197-224_0224.wav\t77441\n']
# ['sam/Amused/amused_197-224_0224.wav\t123859\n', 'bea/Amused/amused_196-224_0224.wav\t61293\n', 'josh/Amused/amused_197-224_0224.wav\t92577\n']
# ['sam/Sleepy/sleepiness_197-224_0224.wav\t89142\n', 'jenie/Sleepy/sleepiness_197-224_0224.wav\t75833\n', 'josh/Sleepy/sleepiness_197-224_0224.wav\t78172\n']
# ['sam/Disgusted/Disgust_197-224_0224.wav\t105151\n', 'bea/Disgusted/disgust_197-224_0224.wav\t72747\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_115_0156.wav
# Words are like banknotes, if you put too many of them in circulation, they lose their value. Look at what's happening on social media today. Everyone is sharing their little thoughts ten or twenty times a day. On every topic. An inflation of fake currency that has devalued the real one. Words no longer mean anything.
#  > Text splitted to sentences.
# ['Words are like banknotes, if you put too many of them in circulation, they lose their value.', "Look at what's happening on social media today.", 'Everyone is sharing their little thoughts ten or twenty times a day.', 'On every topic.', 'An inflation of fake currency that has devalued the real one.', 'Words no longer mean anything.']
#  > Processing time: 0.541316032409668
#  > Real-time factor: 0.023979465032612463
# ['sam/Angry/anger_141-168_0156.wav\t66925\n', 'bea/Angry/anger_169-196_0156.wav\t57081\n', 'jenie/Angry/anger_141-168_0156.wav\t71123\n']
# ['sam/Amused/amused_141-168_0156.wav\t108197\n', 'bea/Amused/amused_141_168_0156.wav\t77991\n', 'josh/Amused/amused_141_168_0156.wav\t58500\n']
# ['sam/Sleepy/sleepiness_141-168_0156.wav\t95942\n', 'bea/Sleepy/sleepiness_141-168_0156.wav\t119068\n', 'jenie/Sleepy/sleepiness_141-168_0156.wav\t73645\n']
# ['bea/Disgusted/disgust_141-168_0156.wav\t114495\n', 'jenie/Disgusted/disgust_141-168_0156.wav\t91195\n', 'sam/Disgusted/Disgust_141-168_0156.wav\t101094\n']
# /home/utilisateur/createch/project/emotion/dataset_test/sam/Neutral/Alexandre_117_0318.wav
# I will be accused of elitism. They'll say that only a select few have the right to express themselves, and that the rest should just keep quiet and listen. That's not true. I believe we should all be quiet.
#  > Text splitted to sentences.
# ['I will be accused of elitism.', "They'll say that only a select few have the right to express themselves, and that the rest should just keep quiet and listen.", "That's not true.", 'I believe we should all be quiet.']
#  > Processing time: 0.36298632621765137
#  > Real-time factor: 0.025107434793149006
# ...
# 2023-12-07 16:23:36 | INFO | fairseq_cli.preprocess | [neutral] Dictionary: 204 types
# 2023-12-07 16:23:36 | INFO | fairseq_cli.preprocess | [neutral] /home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/processed_data_test/neutral-disgusted/test.neutral: 143 sents, 23634 tokens, 0.0% replaced (by <unk>)
# 2023-12-07 16:23:36 | INFO | fairseq_cli.preprocess | [disgusted] Dictionary: 204 types
# 2023-12-07 16:23:36 | INFO | fairseq_cli.preprocess | [disgusted] /home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/processed_data_test/neutral-disgusted/test.disgusted: 143 sents, 18158 tokens, 0.0% replaced (by <unk>)
# 2023-12-07 16:23:36 | INFO | fairseq_cli.preprocess | Wrote preprocessed data to /home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/processed_data_test/neutral-disgusted/tokenized
# ----------------create mafnifest finish----------------
# 2023-12-07 16:23:37 | INFO | fairseq.tasks.text_to_speech | Please install tensorboardX: pip install tensorboardX
# 2023-12-07 16:23:39 | INFO | fairseq_cli.generate | {'_name': None, 'common': {'_name': None, 'no_progress_bar': False, 'log_interval': 100, 'log_format': None, 'log_file': None, 'aim_repo': None, 'aim_run_hash': None, 'tensorboard_logdir': None, 'wandb_project': None, 'azureml_logging': False, 'seed': 1, 'cpu': False, 'tpu': False, 'bf16': False, 'memory_efficient_bf16': False, 'fp16': False, 'memory_efficient_fp16': False, 'fp16_no_flatten_grads': False, 'fp16_init_scale': 128, 'fp16_scale_window': None, 'fp16_scale_tolerance': 0.0, 'on_cpu_convert_precision': False, 'min_loss_scale': 0.0001, 'threshold_loss_scale': None, 'amp': False, 'amp_batch_retries': 2, 'amp_init_scale': 128, 'amp_scale_window': None, 'user_dir': '/home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/fairseq_models', 'empty_cache_freq': 0, 'all_gather_list_size': 16384, 'model_parallel_size': 1, 'quantization_config_path': None, 'profile': False, 'reset_logging': False, 'suppress_crashes': False, 'use_plasma_view': False, 'plasma_path': '/tmp/plasma'}, 'common_eval': {'_name': None, 'path': '/home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/save/train_neutral_disgusted/checkpoint_best.pt', 'post_process': None, 'quiet': False, 'model_overrides': '{}', 'results_path': '/home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/processed_data_test/token'}, 'distributed_training': {'_name': None, 'distributed_world_size': 1, 'distributed_num_procs': 1, 'distributed_rank': 0, 'distributed_backend': 'nccl', 'distributed_init_method': None, 'distributed_port': -1, 'device_id': 0, 'distributed_no_spawn': False, 'ddp_backend': 'pytorch_ddp', 'ddp_comm_hook': 'none', 'bucket_cap_mb': 25, 'fix_batches_to_gpus': False, 'find_unused_parameters': False, 'gradient_as_bucket_view': False, 'fast_stat_sync': False, 'heartbeat_timeout': -1, 'broadcast_buffers': False, 'slowmo_momentum': None, 'slowmo_base_algorithm': 'localsgd', 'localsgd_frequency': 3, 'nprocs_per_node': 1, 'pipeline_model_parallel': False, 'pipeline_balance': None, 'pipeline_devices': None, 'pipeline_chunks': 0, 'pipeline_encoder_balance': None, 'pipeline_encoder_devices': None, 'pipeline_decoder_balance': None, 'pipeline_decoder_devices': None, 'pipeline_checkpoint': 'never', 'zero_sharding': 'none', 'fp16': False, 'memory_efficient_fp16': False, 'tpu': False, 'no_reshard_after_forward': False, 'fp32_reduce_scatter': False, 'cpu_offload': False, 'use_sharded_state': False, 'not_fsdp_flatten_parameters': False}, 'dataset': {'_name': None, 'num_workers': 1, 'skip_invalid_size_inputs_valid_test': True, 'max_tokens': None, 'batch_size': 4, 'required_batch_size_multiple': 8, 'required_seq_len_multiple': 1, 'dataset_impl': None, 'data_buffer_size': 10, 'train_subset': 'train', 'valid_subset': 'valid', 'combine_valid_subsets': None, 'ignore_unused_valid_subsets': False, 'validate_interval': 1, 'validate_interval_updates': 0, 'validate_after_updates': 0, 'fixed_validation_seed': None, 'disable_validation': False, 'max_tokens_valid': None, 'batch_size_valid': 4, 'max_valid_steps': None, 'curriculum': 0, 'gen_subset': 'test', 'num_shards': 1, 'shard_id': 0, 'grouped_shuffling': False, 'update_epoch_batch_itr': False, 'update_ordered_indices_seed': False}, 'optimization': {'_name': None, 'max_epoch': 0, 'max_update': 0, 'stop_time_hours': 0.0, 'clip_norm': 0.0, 'sentence_avg': False, 'update_freq': [1], 'lr': [0.25], 'stop_min_lr': -1.0, 'use_bmuf': False, 'skip_remainder_batch': False, 'debug_param_names': False}, 'checkpoint': {'_name': None, 'save_dir': 'checkpoints', 'restore_file': 'checkpoint_last.pt', 'continue_once': None, 'finetune_from_model': None, 'reset_dataloader': False, 'reset_lr_scheduler': False, 'reset_meters': False, 'reset_optimizer': False, 'optimizer_overrides': '{}', 'save_interval': 1, 'save_interval_updates': 0, 'keep_interval_updates': -1, 'keep_interval_updates_pattern': -1, 'keep_last_epochs': -1, 'keep_best_c ...
# 2023-12-07 16:23:39 | INFO | fairseq.tasks.multilingual_translation | [disgusted] dictionary: 204 types
# 2023-12-07 16:23:39 | INFO | fairseq.tasks.multilingual_translation | [neutral] dictionary: 204 types
# 2023-12-07 16:23:39 | INFO | fairseq_cli.generate | loading model(s) from /home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/save/train_neutral_disgusted/checkpoint_best.pt
# loading pre-trained emotion translation model
# 2023-12-07 16:23:39 | INFO | fairseq.data.data_utils | loaded 143 examples from: /home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/processed_data_test/tokenized/test.neutral-disgusted.neutral
# 2023-12-07 16:23:39 | INFO | fairseq.data.data_utils | loaded 143 examples from: /home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/processed_data_test/tokenized/test.neutral-disgusted.disgusted
# 2023-12-07 16:23:39 | INFO | fairseq.tasks.translation | /home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/processed_data_test/tokenized test neutral-disgusted 143 examples
# 2023-12-07 16:23:39 | INFO | fairseq.tasks.fairseq_task | can_reuse_epoch_itr = True
# 2023-12-07 16:23:39 | INFO | fairseq.tasks.fairseq_task | reuse_dataloader = True
# 2023-12-07 16:23:39 | INFO | fairseq.tasks.fairseq_task | rebuild_batches = False
# 2023-12-07 16:23:39 | INFO | fairseq.tasks.fairseq_task | creating new batches for epoch 1
# 2023-12-07 16:23:55 | INFO | fairseq_cli.generate | NOTE: hypothesis and token scores are output in base 2
# 2023-12-07 16:23:55 | INFO | fairseq_cli.generate | Translated 140 sentences (20,264 tokens) in 14.8s (9.47 sentences/s, 1370.37 tokens/s)
# Loading '/home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/save/hifigan/g_00400000'
# Complete.
# 2023-12-07 16:24:01 | INFO | synthesize_perso | loaded duration prediction model from /home/utilisateur/createch/project/emotion/fairseq/examples/emotion_conversion/save/duration_predictor
# 2023-12-07 16:24:01 | INFO | synthesize_perso | loaded f0 prediction model from CnnPredictor(
#   (token_emb): Embedding(201, 256, padding_idx=200)
#   (gst_emb): Embedding(20, 8)
#   (conv_layer): ModuleList(
#     (0): Sequential(
#       (0): Rearrange('b t c -> b c t')
#       (1): Conv1d(264, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#       (2): Rearrange('b c t -> b t c')
#       (3): ReLU()
#       (4): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (5): Dropout(p=0.1, inplace=False)
#     )
#     (1-5): 5 x Sequential(
#       (0): Rearrange('b t c -> b c t')
#       (1): Conv1d(256, 256, kernel_size=(5,), stride=(1,), padding=(2,))
#       (2): Rearrange('b c t -> b t c')
#       (3): ReLU()
#       (4): LayerNorm((256,), eps=1e-05, elementwise_affine=True)
#       (5): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (proj): Linear(in_features=256, out_features=50, bias=True)
# )
# 0it [00:00, ?it/s]
# /home/utilisateur/createch/project/emotion/dataset_final/disgusted
# outdir: /home/utilisateur/createch/project/emotion/dataset_final/disgusted
# 140
# #######speaker#######
# sam
# sam
# 3
# 1it [00:00,  3.64it/s]
# #######speaker#######
# sam
# sam
# 3
# 2it [00:00,  2.36it/s]
# #######speaker#######
# sam
# sam
# 3
# 3it [00:01,  1.47it/s]
# #######speaker#######
# bea
# bea
# 0
# 4it [00:02,  1.77it/s]
# #######speaker#######
# sam
# sam
# 3
# 5it [00:02,  2.31it/s]
# #######speaker#######
# sam
# sam
# 3
# 6it [00:03,  1.96it/s]
# #######speaker#######
# sam
# sam
# 3
# 7it [00:03,  2.41it/s]
# #######speaker#######
# sam
# sam
# 3
# 8it [00:04,  1.53it/s]
# #######speaker#######
# sam
# sam
# 3
# 9it [00:05,  1.07it/s]
# #######speaker#######
# sam
# sam
# 3
# 10it [00:06,  1.18it/s]
# #######speaker#######
# bea
# bea
# 0
# 11it [00:07,  1.37it/s]
# #######speaker#######
# bea
# bea
# 0
# 12it [00:07,  1.58it/s]
# #######speaker#######
# bea
# bea
# 0
# 13it [00:08,  1.63it/s]
# #######speaker#######
# sam
# sam
# 3
# 14it [00:08,  1.84it/s]
# #######speaker#######
# sam
# sam
# 3
# 16it [00:08,  2.66it/s]
# #######speaker#######
# bea
# bea
# 0
# #######speaker#######
# bea
# bea
# 0
# 17it [00:09,  1.71it/s]
# #######speaker#######
# sam
# sam
# 3
# 18it [00:10,  1.84it/s]
# #######speaker#######
# sam
# sam
# 3
# 19it [00:10,  1.86it/s]
# #######speaker#######
# bea
# bea
# 0
# 20it [00:11,  2.08it/s]
# #######speaker#######
# bea
# bea
# 0
# 21it [00:11,  2.51it/s]
# #######speaker#######
# bea
# bea
# 0
# 22it [00:12,  1.89it/s]
# #######speaker#######
# sam
# sam
# 3
# 23it [00:13,  1.55it/s]
# #######speaker#######
# sam
# sam
# 3
# 24it [00:13,  1.57it/s]
# #######speaker#######
# bea
# bea
# 0
# 25it [00:14,  1.95it/s]
# #######speaker#######
# bea
# bea
# 0
# 26it [00:14,  1.88it/s]
# #######speaker#######
# sam
# sam
# 3
# 27it [00:15,  1.48it/s]
# #######speaker#######
# sam
# sam
# 3
# 28it [00:16,  1.57it/s]
# #######speaker#######
# sam
# sam
# 3
# 29it [00:16,  1.87it/s]
# #######speaker#######
# sam
# sam
# 3
# 30it [00:17,  1.58it/s]
# #######speaker#######
# bea
# bea
# 0
# 31it [00:18,  1.56it/s]
# #######speaker#######
# sam
# sam
# 3
# 32it [00:18,  1.44it/s]
# #######speaker#######
# bea
# bea
# 0
# 33it [00:19,  1.45it/s]
# #######speaker#######
# sam
# sam
# 3
# 34it [00:20,  1.22it/s]
# #######speaker#######
# sam
# sam
# 3
# 35it [00:22,  1.24s/it]
# #######speaker#######
# bea
# bea
# 0
# 36it [00:23,  1.08s/it]
# #######speaker#######
# bea
# bea
# 0
# 37it [00:24,  1.14it/s]
# #######speaker#######
# sam
# sam
# 3
# 38it [00:25,  1.04it/s]
# #######speaker#######
# sam
# sam
# 3
# 39it [00:25,  1.35it/s]
# #######speaker#######
# sam
# sam
# 3
# 40it [00:25,  1.49it/s]
# #######speaker#######
# sam
# sam
# 3
# 41it [00:26,  1.41it/s]
# #######speaker#######
# sam
# sam
# 3
# 42it [00:26,  1.75it/s]
# #######speaker#######
# bea
# bea
# 0
# 43it [00:27,  1.98it/s]
# #######speaker#######
# sam
# sam
# 3
# 44it [00:28,  1.68it/s]
# #######speaker#######
# sam
# sam
# 3
# 45it [00:28,  2.06it/s]
# #######speaker#######
# sam
# sam
# 3
# 46it [00:29,  1.71it/s]
# #######speaker#######
# bea
# bea
# 0
# 47it [00:29,  2.03it/s]
# #######speaker#######
# bea
# bea
# 0
# 48it [00:29,  2.29it/s]
# #######speaker#######
# sam
# sam
# 3
# 49it [00:30,  2.01it/s]
# #######speaker#######
# bea
# bea
# 0
# 50it [00:30,  1.98it/s]
# #######speaker#######
# sam
# sam
# 3
# 52it [00:31,  2.68it/s]
# #######speaker#######
# bea
# bea
# 0
# #######speaker#######
# bea
# bea
# 0
# 53it [00:31,  2.78it/s]
# #######speaker#######
# sam
# sam
# 3
# 54it [00:32,  2.39it/s]
# #######speaker#######
# sam
# sam
# 3
# 55it [00:32,  2.73it/s]
# #######speaker#######
# sam
# sam
# 3
# 56it [00:33,  2.45it/s]
# #######speaker#######
# sam
# sam
# 3
# 57it [00:33,  1.89it/s]
# #######speaker#######
# sam
# sam
# 3
# 58it [00:34,  2.20it/s]
# #######speaker#######
# sam
# sam
# 3
# 59it [00:34,  2.06it/s]
# #######speaker#######
# sam
# sam
# 3
# 60it [00:36,  1.17it/s]
# #######speaker#######
# bea
# bea
# 0
# 61it [00:37,  1.13it/s]
# #######speaker#######
# sam
# sam
# 3
# 62it [00:37,  1.41it/s]
# #######speaker#######
# sam
# sam
# 3
# 63it [00:38,  1.67it/s]
# #######speaker#######
# bea
# bea
# 0
# 65it [00:38,  1.96it/s]
# #######speaker#######
# bea
# bea
# 0
# #######speaker#######
# sam
# sam
# 3
# 66it [00:39,  1.65it/s]
# #######speaker#######
# sam
# sam
# 3
# 67it [00:40,  1.41it/s]
# #######speaker#######
# sam
# sam
# 3
# 68it [00:40,  1.75it/s]
# #######speaker#######
# bea
# bea
# 0
# 69it [00:41,  2.09it/s]
# #######speaker#######
# sam
# sam
# 3
# 70it [00:41,  1.82it/s]
# #######speaker#######
# bea
# bea
# 0
# 71it [00:43,  1.36it/s]
# #######speaker#######
# bea
# bea
# 0
# 72it [00:43,  1.34it/s]
# #######speaker#######
# sam
# sam
# 3
# 73it [00:44,  1.35it/s]
# #######speaker#######
# sam
# sam
# 3
# 74it [00:45,  1.25it/s]
# #######speaker#######
# bea
# bea
# 0
# 75it [00:45,  1.57it/s]
# #######speaker#######
# bea
# bea
# 0
# 76it [00:46,  1.72it/s]
# #######speaker#######
# sam
# sam
# 3
# 77it [00:47,  1.51it/s]
# #######speaker#######
# sam
# sam
# 3
# 78it [00:47,  1.45it/s]
# #######speaker#######
# sam
# sam
# 3
# 79it [00:48,  1.78it/s]
# #######speaker#######
# sam
# sam
# 3
# 80it [00:49,  1.39it/s]
# #######speaker#######
# bea
# bea
# 0
# 82it [00:49,  2.19it/s]
# #######speaker#######
# sam
# sam
# 3
# #######speaker#######
# sam
# sam
# 3
# 83it [00:50,  2.02it/s]
# #######speaker#######
# sam
# sam
# 3
# 84it [00:50,  1.76it/s]
# #######speaker#######
# sam
# sam
# 3
# 85it [00:51,  1.81it/s]
# #######speaker#######
# sam
# sam
# 3
# 86it [00:51,  1.90it/s]
# #######speaker#######
# sam
# sam
# 3
# 87it [00:52,  2.25it/s]
# #######speaker#######
# bea
# bea
# 0
# 88it [00:52,  2.41it/s]
# #######speaker#######
# bea
# bea
# 0
# 89it [00:53,  1.96it/s]
# #######speaker#######
# bea
# bea
# 0
# 90it [00:54,  1.42it/s]
# #######speaker#######
# sam
# sam
# 3
# 91it [00:54,  1.74it/s]
# #######speaker#######
# bea
# bea
# 0
# 92it [00:55,  1.60it/s]
# #######speaker#######
# sam
# sam
# 3
# 93it [00:55,  1.72it/s]
# #######speaker#######
# sam
# sam
# 3
# 94it [00:56,  1.62it/s]
# #######speaker#######
# bea
# bea
# 0
# 95it [00:57,  1.71it/s]
# #######speaker#######
# bea
# bea
# 0
# 96it [00:57,  1.58it/s]
# #######speaker#######
# sam
# sam
# 3
# 97it [00:58,  1.96it/s]
# #######speaker#######
# sam
# sam
# 3
# 98it [00:58,  2.34it/s]
# #######speaker#######
# sam
# sam
# 3
# 99it [01:00,  1.08it/s]
# #######speaker#######
# sam
# sam
# 3
# 100it [01:01,  1.02it/s]
# #######speaker#######
# sam
# sam
# 3
# 101it [01:02,  1.13it/s]
# #######speaker#######
# bea
# bea
# 0
# 102it [01:02,  1.35it/s]
# #######speaker#######
# sam
# sam
# 3
# 103it [01:03,  1.51it/s]
# #######speaker#######
# bea
# bea
# 0
# 104it [01:03,  1.87it/s]
# #######speaker#######
# sam
# sam
# 3
# 105it [01:03,  1.97it/s]
# #######speaker#######
# bea
# bea
# 0
# 106it [01:04,  1.93it/s]
# #######speaker#######
# sam
# sam
# 3
# 107it [01:05,  1.41it/s]
# #######speaker#######
# sam
# sam
# 3
# 108it [01:05,  1.78it/s]
# #######speaker#######
# bea
# bea
# 0
# 109it [01:06,  1.87it/s]
# #######speaker#######
# bea
# bea
# 0
# 110it [01:06,  1.94it/s]
# #######speaker#######
# bea
# bea
# 0
# 111it [01:07,  1.75it/s]
# #######speaker#######
# bea
# bea
# 0
# 112it [01:07,  1.82it/s]
# #######speaker#######
# bea
# bea
# 0
# 113it [01:09,  1.20it/s]
# #######speaker#######
# bea
# bea
# 0
# 114it [01:10,  1.09it/s]
# #######speaker#######
# sam
# sam
# 3
# 115it [01:10,  1.38it/s]
# #######speaker#######
# bea
# bea
# 0
# 116it [01:11,  1.53it/s]
# #######speaker#######
# bea
# bea
# 0
# 117it [01:11,  1.86it/s]
# #######speaker#######
# bea
# bea
# 0
# 118it [01:11,  2.13it/s]
# #######speaker#######
# sam
# sam
# 3
# 119it [01:13,  1.38it/s]
# #######speaker#######
# sam
# sam
# 3
# 120it [01:13,  1.66it/s]
# #######speaker#######
# bea
# bea
# 0
# 121it [01:13,  2.03it/s]
# #######speaker#######
# sam
# sam
# 3
# 122it [01:14,  2.05it/s]
# #######speaker#######
# sam
# sam
# 3
# 123it [01:14,  2.16it/s]
# #######speaker#######
# bea
# bea
# 0
# 124it [01:15,  2.13it/s]
# #######speaker#######
# bea
# bea
# 0
# 125it [01:15,  2.46it/s]
# #######speaker#######
# bea
# bea
# 0
# 126it [01:15,  2.77it/s]
# #######speaker#######
# sam
# sam
# 3
# 127it [01:16,  2.22it/s]
# #######speaker#######
# sam
# sam
# 3
# 128it [01:17,  1.70it/s]
# #######speaker#######
# bea
# bea
# 0
# 129it [01:17,  1.63it/s]
# #######speaker#######
# sam
# sam
# 3
# 130it [01:18,  1.86it/s]
# #######speaker#######
# sam
# sam
# 3
# 131it [01:18,  1.63it/s]
# #######speaker#######
# sam
# sam
# 3
# 132it [01:19,  1.84it/s]
# #######speaker#######
# bea
# bea
# 0
# 133it [01:19,  2.26it/s]
# #######speaker#######
# sam
# sam
# 3
# 134it [01:19,  2.56it/s]
# #######speaker#######
# bea
# bea
# 0
# 135it [01:20,  1.90it/s]
# #######speaker#######
# bea
# bea
# 0
# 136it [01:21,  1.74it/s]
# #######speaker#######
# bea
# bea
# 0
# 137it [01:22,  1.46it/s]
# #######speaker#######
# sam
# sam
# 3
# 138it [01:23,  1.21it/s]
# #######speaker#######
# bea
# bea
# 0
# 139it [01:23,  1.55it/s]
# #######speaker#######
# sam
# sam
# 3
# 140it [01:24,  1.66it/s]
# 2023-12-07 16:25:25 | INFO | synthesize_perso | Done.

# %%
final_dataset_path = "/home/utilisateur/createch/project/emotion/dataset_final_2"

# %%
import glob
if not os.path.exists(final_dataset_path):
    os.makedirs(final_dataset_path)
for index, row in df.iterrows():
    emotion = row['emotion']
    character = row['character']
    emov_charac = dico[character]
    print(row['emotion'])
    audio_name = f"{row['character']}_{row['count_column']}.wav"
    if row['emotion'] != "Neutral":
        print("enter here")
        audio_path = os.path.join(f"/home/utilisateur/createch/project/emotion/dataset_final/{emotion.lower()}", audio_name)
        if not os.path.exists(audio_path):
            print(audio_name)
            search = f"dataset_test/{emov_charac}/Neutral/"+audio_name[:-4]+"_*.wav"
            print(search)
            file_name = glob.glob(search)
            print(file_name)
            shutil.copyfile(file_name[0], os.path.join(f"/home/utilisateur/createch/project/emotion/dataset_final/{emotion.lower()}", audio_name))
        else:
            shutil.copyfile(audio_path, os.path.join(final_dataset_path, audio_name))
    else:
        print("enter there")
        tts.tts_to_file(row['sentence'], file_path = os.path.join(final_dataset_path, audio_name))
# Out:
# Angry
# enter here
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Please don't shoot!"]
#  > Processing time: 0.10365438461303711
#  > Real-time factor: 0.0515885513885308
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Calm down, you see, I'm unarmed .", 'Now please put your gun down.']
#  > Processing time: 0.16825461387634277
#  > Real-time factor: 0.031428014332926926
# Neutral
# enter there
#  > Text splitted to sentences.
# ['What are you doing here?', 'And anyway how did you get in?']
#  > Processing time: 0.18567132949829102
#  > Real-time factor: 0.04528819486103226
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I'll explain everything.", 'Let me catch my breath.']
#  > Processing time: 0.167741060256958
#  > Real-time factor: 0.03693962107168748
# Neutral
# enter there
#  > Text splitted to sentences.
# ['But you are crazy!', 'I almost died of a heart attack!']
#  > Processing time: 0.18596911430358887
#  > Real-time factor: 0.035428350241862513
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I'm sorry, the door was ajar and."]
#  > Processing time: 0.0902857780456543
#  > Real-time factor: 0.03455292637299842
# Neutral
# enter there
#  > Text splitted to sentences.
# ['And you took that as an invitation to come into my house?']
#  > Processing time: 0.08981490135192871
#  > Real-time factor: 0.023438015702637146
# Neutral
# enter there
#  > Text splitted to sentences.
# ['No, but.']
#  > Processing time: 0.08304715156555176
#  > Real-time factor: 0.06110483489123119
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I'm your neighbor."]
#  > Processing time: 0.10034847259521484
#  > Real-time factor: 0.059583256697664996
# Neutral
# enter there
#  > Text splitted to sentences.
# ['The neighbor next door?', 'She is eighty years old.']
#  > Processing time: 0.16611695289611816
#  > Real-time factor: 0.03995286661604936
# Neutral
# enter there
#  > Text splitted to sentences.
# ['The neighbor across the courtyard.', 'window on the public side) The window over there is my apartment.']
#  > Processing time: 0.1689307689666748
#  > Real-time factor: 0.02503847235773271
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Across the courtyard ?', "It's been vacant for years."]
#  > Processing time: 0.16601800918579102
#  > Real-time factor: 0.04229086301463369
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Not anymore.']
#  > Processing time: 0.10054636001586914
#  > Real-time factor: 0.056952508177916014
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Alright.', 'So what?']
#  > Processing time: 0.1806168556213379
#  > Real-time factor: 0.0818253136598147
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Well no, you see.', 'Your cat seems to be better educated than you, apparently.']
#  > Processing time: 0.19693303108215332
#  > Real-time factor: 0.034965000445773324
# Neutral
# enter there
#  > Text splitted to sentences.
# ["She's been missing for two days.", "I've put up posters all over the neighborhood with her name and photo.", "Haven't you seen them?"]
#  > Processing time: 0.28311896324157715
#  > Real-time factor: 0.031216363006424396
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I don't go out much.", 'and I never look at those kinds of ads.', "Besides, I'm not very good at recognizing cats."]
#  > Processing time: 0.28487396240234375
#  > Real-time factor: 0.03206664456715919
# Amused
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["What's gotten into your mind to scream like that?", 'Are you mad?']
#  > Processing time: 0.18821167945861816
#  > Real-time factor: 0.03840379341929348
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Her name is Tofu.']
#  > Processing time: 0.08494901657104492
#  > Real-time factor: 0.044871737624366144
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Your cat's name is Tofu?", 'You must be joking.']
#  > Processing time: 0.1635129451751709
#  > Real-time factor: 0.03988341195920927
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Not at all.', 'Why?']
#  > Processing time: 0.16676688194274902
#  > Real-time factor: 0.07141877227388159
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Okay, your cat's name is Tofu, and it hasn't come home for two days.", "It's not that big of a deal, is it?"]
#  > Processing time: 0.1699233055114746
#  > Real-time factor: 0.023008012910984567
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Well that is quite unfortunate.', 'In my time, cats lived in the countryside, or maybe in a big garden at most.', 'They spent their time chasing mice, and only came back home when they were hungry, so we could feed them, stroke them a little, and let them sleep on the couch.']
#  > Processing time: 0.30926990509033203
#  > Real-time factor: 0.018406935346690294
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I don't eat meat, and neither does my cat."]
#  > Processing time: 0.09086489677429199
#  > Real-time factor: 0.028661750026795867
# Neutral
# enter there
#  > Text splitted to sentences.
# ['What does it eat then?', '4']
#  > Processing time: 0.1868607997894287
#  > Real-time factor: 0.06565975005349475
# Amused
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Do you eat kibbles too?']
#  > Processing time: 0.1185460090637207
#  > Real-time factor: 0.05832603310993935
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Occasionally, yes.', "Well, not the cat's kibbles, of course."]
#  > Processing time: 0.18686962127685547
#  > Real-time factor: 0.03699076369177915
# Neutral
# enter there
#  > Text splitted to sentences.
# ['A vegetarian cat.', "I didn't even know that existed.", "And that's why it's called Tofu?"]
#  > Processing time: 0.26430487632751465
#  > Real-time factor: 0.03877010725799427
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Yes.', "and also because he's a bit crazy."]
#  > Processing time: 0.16660308837890625
#  > Real-time factor: 0.047496872398051344
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Well, she's never complained, that's for sure."]
#  > Processing time: 0.11082673072814941
#  > Real-time factor: 0.029366100420059778
# Neutral
# enter there
#  > Text splitted to sentences.
# ['And.', 'do you think now in circuses, tigers and lions are also fed vegetable kibbles?']
#  > Processing time: 0.2426304817199707
#  > Real-time factor: 0.038980547052965095
# Disgusted
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['But not against indoor cats.']
#  > Processing time: 0.08607840538024902
#  > Real-time factor: 0.033238106588583824
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I gather you don't have any pets."]
#  > Processing time: 0.0844278335571289
#  > Real-time factor: 0.035811667627244775
# Disgusted
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["So you haven't seen my cat?"]
#  > Processing time: 0.10232377052307129
#  > Real-time factor: 0.040791132847008284
# Disgusted
# enter here
# Angry
# enter here
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Didn't you hear any meowing?"]
#  > Processing time: 0.10229015350341797
#  > Real-time factor: 0.05470260682844311
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Meowing?', 'No, not at all.', "But you know, I'm starting to become a little deaf.", 'You will see when you reach my age, there are some advantages.', 'Especially when you have noisy neighbors.']
#  > Processing time: 0.513808012008667
#  > Real-time factor: 0.03950302184376258
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I'm not making any noise, I assure you.", "In fact, I've been living in the apartment right across from yours for over a month, and you thought it was still vacant."]
#  > Processing time: 0.19899892807006836
#  > Real-time factor: 0.017908149258623676
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Alright, I didn't notice your presence, and I hope it stays that way.", 'So if you have nothing else to tell me, I suggest you let me get back to my business and go find your cat.', '5']
#  > Processing time: 0.31746387481689453
#  > Real-time factor: 0.02564657380163156
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Alright, I won't bother you any longer."]
#  > Processing time: 0.08618807792663574
#  > Real-time factor: 0.029335130870003674
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Thank you.']
#  > Processing time: 0.08190202713012695
#  > Real-time factor: 0.06239426818060045
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['What do you mean, like this?']
#  > Processing time: 0.08339095115661621
#  > Real-time factor: 0.0381931387712568
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Well.', 'When I arrived, you were.']
#  > Processing time: 0.18223977088928223
#  > Real-time factor: 0.06152601280176189
# Neutral
# enter there
#  > Text splitted to sentences.
# ['What?']
#  > Processing time: 0.10007452964782715
#  > Real-time factor: 0.10253919046164446
# Neutral
# enter there
#  > Text splitted to sentences.
# ["You didn't seem to be doing well, did you?"]
#  > Processing time: 0.08545088768005371
#  > Real-time factor: 0.02896974282511046
# Neutral
# enter there
#  > Text splitted to sentences.
# ['What makes you think that?']
#  > Processing time: 0.0831906795501709
#  > Real-time factor: 0.04046846285036332
# Disgusted
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Ah, that.', 'So what?']
#  > Processing time: 0.16447901725769043
#  > Real-time factor: 0.06839850502663085
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Well.you look a little.depressed, don't you?"]
#  > Processing time: 0.08534955978393555
#  > Real-time factor: 0.029516276556395524
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Depressed?', 'Listen, miss, when I was your age, the motto of our generation was live fast, die young, and leave a beautiful corpse, does that ring a bell?']
#  > Processing time: 0.17669987678527832
#  > Real-time factor: 0.017471266874351535
# Neutral
# enter there
#  > Text splitted to sentences.
# ['James Dean.']
#  > Processing time: 0.08377933502197266
#  > Real-time factor: 0.05679212792776983
# Disgusted
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I understand.']
#  > Processing time: 0.0820009708404541
#  > Real-time factor: 0.051531047852029555
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I don't think so, no.", "But if you're unfortunate enough to live to my age, you'll see.", 'Old age is a shipwreck.']
#  > Processing time: 0.2578105926513672
#  > Real-time factor: 0.027681747019685655
# Neutral
# enter there
#  > Text splitted to sentences.
# ['De Gaulle.']
#  > Processing time: 0.0999152660369873
#  > Real-time factor: 0.0895873298680697
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Chateaubriand said it before him.', 'But you are right.', 'Aging is going from Rebel Without a Cause to Memoirs from Beyond the Grave.']
#  > Processing time: 0.26927947998046875
#  > Real-time factor: 0.03011448375785795
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Nicely put.']
#  > Processing time: 0.10415387153625488
#  > Real-time factor: 0.06793045632319038
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Yes.', 'The problem is that nowadays, young people already behave like old folks.']
#  > Processing time: 0.18669676780700684
#  > Real-time factor: 0.030050395133617295
# Neutral
# enter there
#  > Text splitted to sentences.
# ["In every era, youth people wanted to change the world, didn't they?", '6']
#  > Processing time: 0.21175789833068848
#  > Real-time factor: 0.03625203150769939
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['And you, have you succeeded in changing the world?']
#  > Processing time: 0.10469174385070801
#  > Real-time factor: 0.03219779279050591
# Amused
# enter here
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Apparently, neither do you.', "Otherwise you wouldn't be in a relationship with a cat."]
#  > Processing time: 0.16788959503173828
#  > Real-time factor: 0.028347567771761128
# Neutral
# enter there
#  > Text splitted to sentences.
# ["At least I'm not alone."]
#  > Processing time: 0.08344769477844238
#  > Real-time factor: 0.03969670499362821
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I don't know.", 'But to change the world, you have to start by saving the planet, right?', "What's the point of staging a revolution on the Titanic?"]
#  > Processing time: 0.3135263919830322
#  > Real-time factor: 0.02953979346083382
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Come on don't say that."]
#  > Processing time: 0.08444666862487793
#  > Real-time factor: 0.042028914842419614
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Unfortunately, literature is not very rock and roll.', 'And most of the time, writers die in their beds.']
#  > Processing time: 0.17018914222717285
#  > Real-time factor: 0.022273685814987898
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Are you a writer?']
#  > Processing time: 0.08404207229614258
#  > Real-time factor: 0.05281371677296922
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You could have hurt yourself.']
#  > Processing time: 0.08736586570739746
#  > Real-time factor: 0.04088322026417899
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I could also have killed you.', "When you break into someone's house, there's always a risk.", "I could have claimed self-defense, I wouldn't have even been convicted.", 'concerned.', ') Are you okay?']
#  > Processing time: 0.4754495620727539
#  > Real-time factor: 0.034902728798354765
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Excuse me, it'll pass.", 'Do you have a glass of water?']
#  > Processing time: 0.18002676963806152
#  > Real-time factor: 0.03846502200115559
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Sit down for a second, I'll get you that."]
#  > Processing time: 0.0908818244934082
#  > Real-time factor: 0.028667089581134855
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Thank you.']
#  > Processing time: 0.08197760581970215
#  > Real-time factor: 0.06245184522956165
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Yes, thank you.']
#  > Processing time: 0.09907317161560059
#  > Real-time factor: 0.056489538532374664
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['So you live alone too?']
#  > Processing time: 0.08394145965576172
#  > Real-time factor: 0.03844527221272736
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Does that look obvious?']
#  > Processing time: 0.08778047561645508
#  > Real-time factor: 0.04419892873910382
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Based on what you just told me, I assume you don't have children either."]
#  > Processing time: 0.09548568725585938
#  > Real-time factor: 0.021470258239432403
# Neutral
# enter there
#  > Text splitted to sentences.
# ["What makes you think that I don't have children?"]
#  > Processing time: 0.08520770072937012
#  > Real-time factor: 0.033656309133752706
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Do you have any?']
#  > Processing time: 0.08289837837219238
#  > Real-time factor: 0.05447988921992257
# Amused
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Madison –Yes.']
#  > Processing time: 0.08228278160095215
#  > Real-time factor: 0.05247383544368911
# Neutral
# enter there
#  > Text splitted to sentences.
# ["If we want to save the planet, we should start by avoiding making children, shouldn't we?"]
#  > Processing time: 0.10581707954406738
#  > Real-time factor: 0.020161642851744488
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['And when you think that France is probably the best country to live in, worldwide.']
#  > Processing time: 0.10062098503112793
#  > Real-time factor: 0.018838241406877215
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Yes, that's why I decided to come and settle in your country."]
#  > Processing time: 0.113525390625
#  > Real-time factor: 0.026858743168253756
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You are not French?']
#  > Processing time: 0.08426761627197266
#  > Real-time factor: 0.04836789199284145
# Neutral
# enter there
#  > Text splitted to sentences.
# ['My name is Madison.', 'I am American.']
#  > Processing time: 0.18250632286071777
#  > Real-time factor: 0.05135086284043011
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Yet you speak our language fluently, and without any accent.']
#  > Processing time: 0.10299086570739746
#  > Real-time factor: 0.02315782130902384
# Neutral
# enter there
#  > Text splitted to sentences.
# ['My grandmother was French.', 'She taught me the language of Molière.', 'I came to Paris to study literature at the Sorbonne.']
#  > Processing time: 0.29943060874938965
#  > Real-time factor: 0.03235223894023933
# Neutral
# enter there
#  > Text splitted to sentences.
# ["So it's just a coincidence that I find you today on my way to Madison."]
#  > Processing time: 0.11130332946777344
#  > Real-time factor: 0.02282248191084292
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Your name is Alexandre, isn't it?", '8']
#  > Processing time: 0.20300602912902832
#  > Real-time factor: 0.05730595737268376
# Neutral
# enter there
#  > Text splitted to sentences.
# ['How do you know?']
#  > Processing time: 0.10097670555114746
#  > Real-time factor: 0.0776121150795734
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I saw your name on the mailbox downstairs.', 'Alexandre Delacroix.', 'Are you related to.']
#  > Processing time: 0.284576416015625
#  > Real-time factor: 0.037756991751375105
# Neutral
# enter there
#  > Text splitted to sentences.
# ['The painter?', 'No not at all.']
#  > Processing time: 0.18094325065612793
#  > Real-time factor: 0.06802029932091552
# Neutral
# enter there
#  > Text splitted to sentences.
# ['The writer!']
#  > Processing time: 0.08210468292236328
#  > Real-time factor: 0.07138833826648701
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You are American and you know Alexandre Delacroix.', 'whom no body in France remembers anymore.']
#  > Processing time: 0.22002196311950684
#  > Real-time factor: 0.030659026079279103
# Neutral
# enter there
#  > Text splitted to sentences.
# ["You're exaggerating.", 'Everyone knows Alexandre Delacroix.', 'And his fame has gone far beyond the borders of France.', 'Among those who are interested in literature, at least.', 'So ?']
#  > Processing time: 0.4620950222015381
#  > Real-time factor: 0.03436166311290642
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Yes.', 'It is me.']
#  > Processing time: 0.1639864444732666
#  > Real-time factor: 0.07429119618334008
# Neutral
# enter there
#  > Text splitted to sentences.
# ['No?', 'Alexandre Delacroix, that mythical author who has signed several masterpieces in the 20th-century literature!']
#  > Processing time: 0.1884615421295166
#  > Real-time factor: 0.022081581597282778
# Neutral
# enter there
#  > Text splitted to sentences.
# ['If you say so.']
#  > Processing time: 0.0846707820892334
#  > Real-time factor: 0.04613954984844791
# Neutral
# enter there
#  > Text splitted to sentences.
# ["A mysterious writer who now lives as a recluse, who hasn't published anything for years, and who refuses all interviews.", 'Is that really you?']
#  > Processing time: 0.23624849319458008
#  > Real-time factor: 0.023494007409711404
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Something tells me that you already knew that before breaking into my house by forcing my door, am I wrong?']
#  > Processing time: 0.12197470664978027
#  > Real-time factor: 0.018725230322126373
# Neutral
# enter there
#  > Text splitted to sentences.
# ['No, I admit it.']
#  > Processing time: 0.08460783958435059
#  > Real-time factor: 0.046105250663180365
# Neutral
# enter there
#  > Text splitted to sentences.
# ['So you made up this story about a cat to try to get an interview.']
#  > Processing time: 0.08608436584472656
#  > Real-time factor: 0.01812605296864229
# Neutral
# enter there
#  > Text splitted to sentences.
# ["It's true about the cat, I swear.", "But it's also true that when I moved in just across your home, I had an idea in mind."]
#  > Processing time: 0.23107290267944336
#  > Real-time factor: 0.02493714518442505
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Did you deliberately rent an apartment opposite mine just to spy on me?']
#  > Processing time: 0.09607315063476562
#  > Real-time factor: 0.020893295047899066
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["And what part of that sentence didn't you understand?"]
#  > Processing time: 0.09528374671936035
#  > Real-time factor: 0.026814971094061363
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I crossed the Atlantic in the hope of meeting you.', 'I was looking for an apartment, and the one across from yours was available for rent, so I jumped at the opportunity.', '9']
#  > Processing time: 0.3031892776489258
#  > Real-time factor: 0.025648070913997043
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I'm a student, as I told you.", "I wrote my master's thesis on your work in New York.", 'And then I decided to come to Paris to continue my research, since this city is the setting for most of your novels.', 'You know, for Americans, Paris is the most romantic city in the world.']
#  > Processing time: 0.4236416816711426
#  > Real-time factor: 0.02171667878861194
# Neutral
# enter there
#  > Text splitted to sentences.
# ['And with a cliché like that, you think you can shed light on the hidden meaning of my work?']
#  > Processing time: 0.13899683952331543
#  > Real-time factor: 0.029629546708131338
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Do you want to know the title of my thesis?']
#  > Processing time: 0.10453033447265625
#  > Real-time factor: 0.03529915883242573
# Neutral
# enter there
#  > Text splitted to sentences.
# ['No.']
#  > Processing time: 0.10024476051330566
#  > Real-time factor: 0.10032665982745052
# Neutral
# enter there
#  > Text splitted to sentences.
# ['"The figure of absence in the fictional universe of Alexandre Delacroix."']
#  > Processing time: 0.10558390617370605
#  > Real-time factor: 0.022846258548538022
# Neutral
# enter there
#  > Text splitted to sentences.
# ["You've got it all figured out.", 'What I like most about most people, including you, is their absence.', "That's why I'm asking you to leave."]
#  > Processing time: 0.2704885005950928
#  > Real-time factor: 0.026499393252478298
# Neutral
# enter there
#  > Text splitted to sentences.
# ["When you have the chance to work on a living author, you want to meet him, it's normal.", 'To know him a little better.', 'And by knowing about his life, it provides a better understanding of his work.']
#  > Processing time: 0.2577500343322754
#  > Real-time factor: 0.020764117967157714
# Neutral
# enter there
#  > Text splitted to sentences.
# ["It's a mistake, I assure you.", "It's better to be content with studying the work while ignoring everything about the author.", 'Many great writers were very small characters in life.', "If they weren't complete assholes.", 'And that goes either artists or scientists.', "That's how it is.", 'Geniuses rarely benefit from being known.', "Even though, I don't consider myself a genius."]
#  > Processing time: 0.8129212856292725
#  > Real-time factor: 0.030317902867445363
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I understand your modesty, but still.', 'An exclusive interview with the author of "Chronicles of the Latin Quarter" would be the crowning achievement of my research.']
#  > Processing time: 0.22937226295471191
#  > Real-time factor: 0.021973004996834584
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Have you read it?']
#  > Processing time: 0.08394932746887207
#  > Real-time factor: 0.05735878379674731
# Amused
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['However, it is not the best-selling.']
#  > Processing time: 0.10572504997253418
#  > Real-time factor: 0.0401052393320668
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I imagine this novel is largely autobiographical.']
#  > Processing time: 0.08566594123840332
#  > Real-time factor: 0.02208762867524314
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I told you.', 'It has no interest for the reader.']
#  > Processing time: 0.18703603744506836
#  > Real-time factor: 0.04614375923809252
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Not to mention that mysterious manuscript you've been working on for years."]
#  > Processing time: 0.10586977005004883
#  > Real-time factor: 0.02150357801771902
# Angry
# enter here
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['What do you mean, no?']
#  > Processing time: 0.08396768569946289
#  > Real-time factor: 0.04435337939998938
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Go back where you came from on your pedalo if you wish, it's not my problem."]
#  > Processing time: 0.10341906547546387
#  > Real-time factor: 0.020761019607920414
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I'm not pretending, I assure you."]
#  > Processing time: 0.08607912063598633
#  > Real-time factor: 0.029182727706388353
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Do you want me to call an ambulance?']
#  > Processing time: 0.08896636962890625
#  > Real-time factor: 0.03114218393315632
# Neutral
# enter there
#  > Text splitted to sentences.
# ['No, but I need to sit down for a moment.']
#  > Processing time: 0.08463668823242188
#  > Real-time factor: 0.02462316571042989
# Neutral
# enter there
#  > Text splitted to sentences.
# ['And then you will leave?']
#  > Processing time: 0.08325386047363281
#  > Real-time factor: 0.04452240064618751
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I promise.']
#  > Processing time: 0.09781503677368164
#  > Real-time factor: 0.06790999876762217
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I already gave you a glass of water.', 'Do you want a glass of brandy?']
#  > Processing time: 0.16747379302978516
#  > Real-time factor: 0.030880361388703863
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Are you trying to finish me off, is that it?']
#  > Processing time: 0.11721062660217285
#  > Real-time factor: 0.03657027276117715
# Neutral
# enter there
#  > Text splitted to sentences.
# ["It's too late, unfortunately.", 'I should have shot you right away, I would have pleaded self-defense.', 'Now I can no longer deny premeditation.']
#  > Processing time: 0.33481431007385254
#  > Real-time factor: 0.031069690328632955
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Why do you keep a gun at home?']
#  > Processing time: 0.08482551574707031
#  > Real-time factor: 0.03562943123710188
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Initially, it was to ward off intruders.', "Apparently, it's not enough."]
#  > Processing time: 0.18017935752868652
#  > Real-time factor: 0.03280180674956686
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Even if you are a bit misanthropic, like many writers.', "We all need friendship, don't we?"]
#  > Processing time: 0.22965312004089355
#  > Real-time factor: 0.034940462139142904
# Disgusted
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Doesn't loneliness weigh on you at all?"]
#  > Processing time: 0.1111290454864502
#  > Real-time factor: 0.03666500258822461
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Loneliness.', "It's like coffee.", "At first, it's a little bitter.", 'Then you get used to it.', 'After that, you develop a taste for it.', "And finally, we can't do without it."]
#  > Processing time: 0.5565128326416016
#  > Real-time factor: 0.039733926405771794
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You should write a collection of aphorisms.', "I'm sure it would sell very well."]
#  > Processing time: 0.1956944465637207
#  > Real-time factor: 0.035106926473656284
# Neutral
# enter there
#  > Text splitted to sentences.
# ['And then what is it, not being alone?', 'Living as a couple and rehashing the same banalities year after year?', 'Seeing family or friends from time to time, carefully avoiding any important topics that could cause conflict?', 'Running into neighbors in the stairwell and discussing the weather?', 'Talking to your cat as if it understands you?']
#  > Processing time: 0.47497034072875977
#  > Real-time factor: 0.021426838875800255
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Yet, when you write, however, you are addressing someone.']
#  > Processing time: 0.1066591739654541
#  > Real-time factor: 0.029629041346732804
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I don't believe you."]
#  > Processing time: 0.08282661437988281
#  > Real-time factor: 0.04630646163986856
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["So you don't want to grant me this interview?"]
#  > Processing time: 0.10266733169555664
#  > Real-time factor: 0.03638169619257881
# Sleepy
# enter here
# Sleepy
# enter here
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Mine might be too, perhaps.']
#  > Processing time: 0.08842706680297852
#  > Real-time factor: 0.03541515589591827
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You are forty years younger than me. I could be your father.']
#  > Processing time: 0.10460638999938965
#  > Real-time factor: 0.024281738456781013
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Or even my grandfather.']
#  > Processing time: 0.08313441276550293
#  > Real-time factor: 0.03728265948339041
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Thank you for this precision, it is very kind of you.', 'Nevertheless, your life is just beginning.']
#  > Processing time: 0.2188277244567871
#  > Real-time factor: 0.0321573851319055
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['What do you mean?']
#  > Processing time: 0.08282184600830078
#  > Real-time factor: 0.05281761061091601
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I have a heart disease.', 'Doctors have given me only a few years to live.', 'Maybe just a few months.', "That's why I came to France to fulfill one last dream.", 'To meet you.']
#  > Processing time: 0.507185697555542
#  > Real-time factor: 0.03707448625914875
# Neutral
# enter there
#  > Text splitted to sentences.
# ['What do you mean by heart disease?']
#  > Processing time: 0.08562231063842773
#  > Real-time factor: 0.03321087724418329
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I was born with a heart defect.', 'My heart is too fragile.', 'It could fail at any moment.']
#  > Processing time: 0.29671168327331543
#  > Real-time factor: 0.0413411979083043
# Neutral
# enter there
#  > Text splitted to sentences.
# ['And is that the reason for your moments of weakness?']
#  > Processing time: 0.08501076698303223
#  > Real-time factor: 0.02473199561927196
# Neutral
# enter there
#  > Text splitted to sentences.
# ['At the slightest upset, my heart races, and it can stop beating.']
#  > Processing time: 0.11851215362548828
#  > Real-time factor: 0.023462801568039943
# Angry
# enter here
# Sleepy
# enter here
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["It's not your fault."]
#  > Processing time: 0.10001945495605469
#  > Real-time factor: 0.05416082961151782
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I can't change it, so what's the point of rebelling?"]
#  > Processing time: 0.10974693298339844
#  > Real-time factor: 0.03139817147970645
# Neutral
# enter there
#  > Text splitted to sentences.
# ["And on top of that, you're still smiling."]
#  > Processing time: 0.10341978073120117
#  > Real-time factor: 0.032984352075951545
# Amused
# enter here
# Amused
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I don't have time for doubt anymore.", "That's why I forced your door."]
#  > Processing time: 0.16637206077575684
#  > Real-time factor: 0.032633290101991154
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Yes, a transplant.', 'Still I need to find a donor.']
#  > Processing time: 0.1700289249420166
#  > Real-time factor: 0.037252959012037616
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I'm afraid it's not that simple.", 'Especially for a heart.', "It's not like these organs that we have in pairs.", 'The kidneys, the lungs.']
#  > Processing time: 0.3779935836791992
#  > Real-time factor: 0.03762802712423406
# Neutral
# enter there
#  > Text splitted to sentences.
# ['The testicles.']
#  > Processing time: 0.09972190856933594
#  > Real-time factor: 0.06455108278399065
# Neutral
# enter there
#  > Text splitted to sentences.
# ['For the heart, the donor has to be brain dead.']
#  > Processing time: 0.08432555198669434
#  > Real-time factor: 0.024045344782053203
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Brain dead?', 'Sometimes I wonder if I am not already there.', 'Like many people around me, actually.', '13']
#  > Processing time: 0.3596522808074951
#  > Real-time factor: 0.038953615175088746
# Neutral
# enter there
#  > Text splitted to sentences.
# ['The donor has to be deceased, his heart in good shape, and the organ must be removed quickly.', 'Unfortunately, that rarely happens.', 'And the waiting list for organ transplants is very long.']
#  > Processing time: 0.3038663864135742
#  > Real-time factor: 0.023789459965699426
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I heard that in China, they take organs from death row inmates.', "It's much more convenient, obviously.", 'They set the transplantation date and execute the inmate on the same day.']
#  > Processing time: 0.3159513473510742
#  > Real-time factor: 0.026037221226346895
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Yes, but that way.', 'the recipient has enough time to leisurely fly in from Europe or the United States.', 'Some even take the opportunity to do some sightseeing.', "Of course, it's not free.", "I don't know how much a heart costs in China.", 'Have you looked into it?']
#  > Processing time: 0.5814564228057861
#  > Real-time factor: 0.03081287520876813
# Neutral
# enter there
#  > Text splitted to sentences.
# ['No.']
#  > Processing time: 0.0826117992401123
#  > Real-time factor: 0.08267929254014508
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You should be able to find that easily on the internet.']
#  > Processing time: 0.08380985260009766
#  > Real-time factor: 0.022207354953760736
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Thank you.']
#  > Processing time: 0.08141207695007324
#  > Real-time factor: 0.06202101633323366
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I'm sorry, I shouldn't joke about it.", 'especially not with you.', "But then again, humor is all we have left, isn't it?"]
#  > Processing time: 0.28714466094970703
#  > Real-time factor: 0.032364540432756606
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Yes.']
#  > Processing time: 0.08136320114135742
#  > Real-time factor: 0.0909397093048931
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Even though what I just told you is anything but a joke.']
#  > Processing time: 0.08529424667358398
#  > Real-time factor: 0.024082387563415884
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I would rather die than live with the heart of a death row guy, even yours.', 'So?']
#  > Processing time: 0.19943594932556152
#  > Real-time factor: 0.035703776002116064
# Neutral
# enter there
#  > Text splitted to sentences.
# ['So what?']
#  > Processing time: 0.08222699165344238
#  > Real-time factor: 0.06871987439199533
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["You are quite stubborn, aren't you."]
#  > Processing time: 0.08519959449768066
#  > Real-time factor: 0.03246217615900364
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I'll take that as a compliment."]
#  > Processing time: 0.08480715751647949
#  > Real-time factor: 0.035796282986952005
# Neutral
# enter there
#  > Text splitted to sentences.
# ["But how do I know you're not lying?"]
#  > Processing time: 0.08274006843566895
#  > Real-time factor: 0.034753476626914435
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Who would make up such a story?', 'Just to get an interview with a writer that everyone has already forgotten.']
#  > Processing time: 0.16623902320861816
#  > Real-time factor: 0.0241817768481504
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You finally admit that everyone has already forgotten Alexandre Delacroix.']
#  > Processing time: 0.11409211158752441
#  > Real-time factor: 0.020817316467834912
# Neutral
# enter there
#  > Text splitted to sentences.
# ['So is that a yes?']
#  > Processing time: 0.08298635482788086
#  > Real-time factor: 0.044937355696335286
# Neutral
# enter there
#  > Text splitted to sentences.
# ['As soon as you show me a medical file to prove you are not lying.']
#  > Processing time: 0.08517241477966309
#  > Real-time factor: 0.01820099769239001
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You live just across the courtyard.', 'Go get it.', '14']
#  > Processing time: 0.26401209831237793
#  > Real-time factor: 0.05131034733983159
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I thought you could take my word for it.', 'I must say, I am a little disappointed.']
#  > Processing time: 0.17621684074401855
#  > Real-time factor: 0.027440546175180856
# Neutral
# enter there
#  > Text splitted to sentences.
# ['If I grant you this interview, it is just the beginning, believe me. I am a very disappointing person, you will see.', 'She gets up and looks around the room.', 'Her gaze falls on an old typewriter.']
#  > Processing time: 0.2825047969818115
#  > Real-time factor: 0.02141630031027884
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Do you still write on a typewriter?']
#  > Processing time: 0.10219240188598633
#  > Real-time factor: 0.04250947897649409
# Neutral
# enter there
#  > Text splitted to sentences.
# ['It is indeed on this machine that I wrote all my novels.', "But don't try to trap me. I told you that I haven't written for years."]
#  > Processing time: 0.20497441291809082
#  > Real-time factor: 0.022316350355723172
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Why?']
#  > Processing time: 0.08169031143188477
#  > Real-time factor: 0.08679989239943423
# Disgusted
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["You can't stop people from chatting.", "Before, it was at the café, today it's on Facebook.", 'But there will always be great authors, like you.']
#  > Processing time: 0.3065929412841797
#  > Real-time factor: 0.03139337225702208
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Great authors are no longer read.', 'They are quoted.', 'Incorrectly and indiscriminately.', 'The same quotes repeated over and over until they are completely emptied of meaning.', 'Copy and paste has replaced thinking.', 'and emojis have replaced emotions.']
#  > Processing time: 0.6164565086364746
#  > Real-time factor: 0.03456000837867715
# Neutral
# enter there
#  > Text splitted to sentences.
# ['May I quote you in the conclusion of my thesis?']
#  > Processing time: 0.10593724250793457
#  > Real-time factor: 0.027898865341342886
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['What do you suggest?', 'A minute of silence ?']
#  > Processing time: 0.18209075927734375
#  > Real-time factor: 0.04192178877866511
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Not just a minute.', 'A whole year.', 'A century.', 'A millennium of silence.', 'Maybe then our words would regain meaning after the verbal diarrhea that has flooded social media in recent years.']
#  > Processing time: 0.45034241676330566
#  > Real-time factor: 0.031917106870760124
# Neutral
# enter there
#  > Text splitted to sentences.
# ["It's an interesting analysis, but it's also said that you stopped writing because of a broken heart?"]
#  > Processing time: 0.11307311058044434
#  > Real-time factor: 0.018202182048671283
# Neutral
# enter there
#  > Text splitted to sentences.
# ['People say what we want.']
#  > Processing time: 0.10007691383361816
#  > Real-time factor: 0.045353007851678735
# Neutral
# enter there
#  > Text splitted to sentences.
# ["But you don't deny it either."]
#  > Processing time: 0.09983396530151367
#  > Real-time factor: 0.04408320520062432
# Neutral
# enter there
#  > Text splitted to sentences.
# ["That doesn't mean it's true."]
#  > Processing time: 0.08176732063293457
#  > Real-time factor: 0.041171205241966734
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Who is this woman in the photo?', '15']
#  > Processing time: 0.1832718849182129
#  > Real-time factor: 0.050093527648336404
# Neutral
# enter there
#  > Text splitted to sentences.
# ["That's none of your business."]
#  > Processing time: 0.08236980438232422
#  > Real-time factor: 0.036748425595464734
# Amused
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Even if you are really sick, it doesn't give you the right to pry into my private life."]
#  > Processing time: 0.12636494636535645
#  > Real-time factor: 0.021090794684480666
# Amused
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['She is a woman I loved a very long time ago.']
#  > Processing time: 0.08592391014099121
#  > Real-time factor: 0.024746894182456323
# Neutral
# enter there
#  > Text splitted to sentences.
# ['When you were a hippie?']
#  > Processing time: 0.1001443862915039
#  > Real-time factor: 0.06158477570637163
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Actually, I wasn't much of a hippie.", 'I was open to new ideas.', 'And I smoked a joint from time to time.', 'But I took care of my health and already thought about my career.', 'You need a certain comfort to write, you know?', 'To become a great writer, sometimes you have to remain a little bourgeois.']
#  > Processing time: 0.5429205894470215
#  > Real-time factor: 0.026177749539279146
# Neutral
# enter there
#  > Text splitted to sentences.
# ['And her?']
#  > Processing time: 0.08253192901611328
#  > Real-time factor: 0.06766169820067287
# Neutral
# enter there
#  > Text splitted to sentences.
# ['She was a free woman.', 'She only thought about the present moment.', 'She lived day to day.']
#  > Processing time: 0.2633697986602783
#  > Real-time factor: 0.0392342994031668
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Where did you meet her?']
#  > Processing time: 0.10085749626159668
#  > Real-time factor: 0.05907107396324391
# Neutral
# enter there
#  > Text splitted to sentences.
# ['In the courtyard.', 'She lived in the apartment across from mine.', "The one you're staying in now.", 'Well, she shared it with friends passing by.', 'People who came from all over the world.', 'Musicians, artists.', "That apartment was a bit like Maxime Le Forestier's Maison Bleue.", 'The door was always open.']
#  > Processing time: 0.7706644535064697
#  > Real-time factor: 0.03467197538484603
# Neutral
# enter there
#  > Text splitted to sentences.
# ['And since the door was open, one day she took the opportunity to leave.', 'Like my cat.']
#  > Processing time: 0.17065834999084473
#  > Real-time factor: 0.02716430337042422
# Sleepy
# enter here
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Yes.', 'In her own way, I think.', "Even if she didn't love only me."]
#  > Processing time: 0.26233911514282227
#  > Real-time factor: 0.050304173237261995
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Free love.']
#  > Processing time: 0.08116674423217773
#  > Real-time factor: 0.06718193357055251
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['So, you let her continue her journey alone.', '16']
#  > Processing time: 0.18698644638061523
#  > Real-time factor: 0.040658046137312304
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Where to?']
#  > Processing time: 0.0995485782623291
#  > Real-time factor: 0.09848555952460322
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Afghanistan.', 'It sounds surreal today, but at that time, it was a very popular destination for hippies.', 'Hashish was freely available and very cheap.', 'By working here for a year, you could live there for a year.', 'And then there was this fascination for the East.', 'For hippies in France, Afghanistan was a paradise.']
#  > Processing time: 0.5440673828125
#  > Real-time factor: 0.0234149291717718
# Neutral
# enter there
#  > Text splitted to sentences.
# ['But you stayed.']
#  > Processing time: 0.10637164115905762
#  > Real-time factor: 0.061464745481059235
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You could have gone with her anyway.', 'For love.']
#  > Processing time: 0.16474151611328125
#  > Real-time factor: 0.04775650018797133
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Of course.', 'And she probably would have let me go with her.', "But her dream wasn't a romantic trip.", 'Even less a honeymoon.', 'Asia was an initiatory journey.', 'One that you did with others.', 'Far from the bourgeois patterns of love between two people.']
#  > Processing time: 0.6459732055664062
#  > Real-time factor: 0.03647444683579316
# Neutral
# enter there
#  > Text splitted to sentences.
# ['So you stayed in Paris.', 'but you never forgot her.']
#  > Processing time: 0.16921591758728027
#  > Real-time factor: 0.03670139855602308
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Didn't you try to find her?"]
#  > Processing time: 0.099395751953125
#  > Real-time factor: 0.045282568813355496
# Neutral
# enter there
#  > Text splitted to sentences.
# ["The Internet didn't exist yet.", 'When someone chose to disappear from your life, they really disappeared.', 'And then the years passed.']
#  > Processing time: 0.2658209800720215
#  > Real-time factor: 0.028902133188304112
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You could try to find her now.']
#  > Processing time: 0.08339643478393555
#  > Real-time factor: 0.03403337627675782
# Neutral
# enter there
#  > Text splitted to sentences.
# ["What's the point?", 'She might be dead now.', "Or maybe she's married, has five kids, and weighs 120 kilos."]
#  > Processing time: 0.28360629081726074
#  > Real-time factor: 0.03200760949410674
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Or maybe she's alive, she's still a beautiful woman, and she sometimes thinks of you."]
#  > Processing time: 0.11058568954467773
#  > Real-time factor: 0.01828006517977198
# Neutral
# enter there
#  > Text splitted to sentences.
# ['In doubt, I prefer not to know.', 'and keep the image of that beautiful young woman you see in this photo.', 'Can you imagine the shock, forty years later?', "We don't see ourselves aging, but we see others aging very well, believe me."]
#  > Processing time: 0.3576676845550537
#  > Real-time factor: 0.022239251839804793
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I'm not sure that I will see myself aging."]
#  > Processing time: 0.08488273620605469
#  > Real-time factor: 0.02529276126139873
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Sorry, I shouldn't have said that."]
#  > Processing time: 0.10028409957885742
#  > Real-time factor: 0.03855063451383902
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Didn't you hear meowing?", '17']
#  > Processing time: 0.2030925750732422
#  > Real-time factor: 0.06803280384608942
# Neutral
# enter there
#  > Text splitted to sentences.
# ['No.', 'Still not.']
#  > Processing time: 0.17653751373291016
#  > Real-time factor: 0.07101306512351628
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Maybe she's hiding somewhere here."]
#  > Processing time: 0.09143710136413574
#  > Real-time factor: 0.034685316630181554
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I hope not.']
#  > Processing time: 0.08027863502502441
#  > Real-time factor: 0.05275822312535134
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Promise me that if I die, you'll take care of my cat."]
#  > Processing time: 0.10293793678283691
#  > Real-time factor: 0.026149556521446477
# Neutral
# enter there
#  > Text splitted to sentences.
# ["But come on, you're not going to die!", 'And besides, your cat will probably die before you.', 'Well, I think.', 'How long do cats live?']
#  > Processing time: 0.3491787910461426
#  > Real-time factor: 0.03520720086409608
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['How old is yours?']
#  > Processing time: 0.0821542739868164
#  > Real-time factor: 0.04811681208588243
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Two.']
#  > Processing time: 0.09987807273864746
#  > Real-time factor: 0.11615567003624348
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Exactly, that would give you a reason not to commit suicide.']
#  > Processing time: 0.10596179962158203
# ...
# Neutral
# enter there
#  > Text splitted to sentences.
# ["So you didn't plan to put an end to your life?", '24']
#  > Processing time: 0.18480896949768066
#  > Real-time factor: 0.03919511558771794
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['So our meeting was just a misunderstanding?']
#  > Processing time: 0.10942721366882324
#  > Real-time factor: 0.03294830212745183
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I find it hard to believe that someone would cross the Atlantic just to interview a writer like me.', "And I don't believe in coincidence.", 'So why are you here?']
#  > Processing time: 0.2938406467437744
#  > Real-time factor: 0.027355883354304136
# Amused
# enter here
# Amused
# enter here
# Amused
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Here we go.', 'I was expecting that.', "I'm listening."]
#  > Processing time: 0.24982643127441406
#  > Real-time factor: 0.05350303816628623
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I didn't find the ending quite convincing."]
#  > Processing time: 0.08501744270324707
#  > Real-time factor: 0.02815781380086815
# Neutral
# enter there
#  > Text splitted to sentences.
# ["You're right.", "It's an unfinished story.", 'As if an epilogue lacked.']
#  > Processing time: 0.2539536952972412
#  > Real-time factor: 0.04593515373822162
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I could help you find it.']
#  > Processing time: 0.10071420669555664
#  > Real-time factor: 0.04090679814391806
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Do you write too?', 'Did you come here to propose a collaboration?', "It's true, I'm starting to lack some inspiration, but I have to warn you, I'm not yet at the point of looking for a ghostwriter to write my books for me."]
#  > Processing time: 0.3337249755859375
#  > Real-time factor: 0.022827951157957518
# Neutral
# enter there
#  > Text splitted to sentences.
# ["No, I didn't come for that."]
#  > Processing time: 0.08292436599731445
#  > Real-time factor: 0.03757979016443571
# Neutral
# enter there
#  > Text splitted to sentences.
# ['And this thesis story is also a lie.', "So it's not just for the privilege of a literary chat with me that you played this charade."]
#  > Processing time: 0.2343463897705078
#  > Real-time factor: 0.026108214907233713
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I think the answer is in the manuscript I've just read.", 'The window across the courtyard.', 'Why that title?']
#  > Processing time: 0.2888321876525879
#  > Real-time factor: 0.036521411010984745
# Neutral
# enter there
#  > Text splitted to sentences.
# ['The window across the courtyard.', 'it is the one in the apartment you live in now.', "It's where the woman I once loved used to live."]
#  > Processing time: 0.27182555198669434
#  > Real-time factor: 0.029369626721416162
# Neutral
# enter there
#  > Text splitted to sentences.
# ['And who has been haunting your thoughts since she went away.']
#  > Processing time: 0.10471606254577637
#  > Real-time factor: 0.030882050865803135
# Amused
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["That's why you always leave it open.", '25']
#  > Processing time: 0.16205263137817383
#  > Real-time factor: 0.03854483648913459
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Sometimes, I thought I saw a shadow behind the curtains of the window across.', 'When you moved in, and I saw lights at night, I imagined it was her.']
#  > Processing time: 0.20529484748840332
#  > Real-time factor: 0.02020582500321067
# Neutral
# enter there
#  > Text splitted to sentences.
# ['It was just me.']
#  > Processing time: 0.08182811737060547
#  > Real-time factor: 0.0454531939747544
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You look a bit like her.', "That's why when I saw you earlier for the first time, I cringed.", 'For a moment I thought it was her when she was twenty.', 'And then I remembered that today she would be about the same age as me.']
#  > Processing time: 0.3771476745605469
#  > Real-time factor: 0.025393621213785113
# Neutral
# enter there
#  > Text splitted to sentences.
# ["It's true, I look like her."]
#  > Processing time: 0.08294916152954102
#  > Real-time factor: 0.03417468258083669
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Don't tell me you're her ghost."]
#  > Processing time: 0.09979796409606934
#  > Real-time factor: 0.04429438623829165
# Neutral
# enter there
#  > Text splitted to sentences.
# ["No, I'm very much real."]
#  > Processing time: 0.09936642646789551
#  > Real-time factor: 0.04113528281047416
# Neutral
# enter there
#  > Text splitted to sentences.
# ["But there is something else, isn't there?"]
#  > Processing time: 0.10115456581115723
#  > Real-time factor: 0.0337620818620734
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Yes.']
#  > Processing time: 0.07712626457214355
#  > Real-time factor: 0.08620408220882834
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Why did you say her face looked familiar to you?']
#  > Processing time: 0.0861811637878418
#  > Real-time factor: 0.024095844257480112
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I'm her granddaughter."]
#  > Processing time: 0.09763288497924805
#  > Real-time factor: 0.059195037224824554
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Her granddaughter?']
#  > Processing time: 0.07776165008544922
#  > Real-time factor: 0.054426243790761664
# Neutral
# enter there
#  > Text splitted to sentences.
# ['When she left for Afghanistan, she was pregnant.', 'She found out shortly after she left.']
#  > Processing time: 0.20208454132080078
#  > Real-time factor: 0.028622585663692558
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Pregnant?', 'Me?']
#  > Processing time: 0.17540264129638672
#  > Real-time factor: 0.08341158213822739
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Yes.']
#  > Processing time: 0.07717204093933105
#  > Real-time factor: 0.08625524648784721
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Why didn't she tell me anything?"]
#  > Processing time: 0.09777951240539551
#  > Real-time factor: 0.04230844286771921
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You said it yourself.', 'It was a different time.', "She didn't want to impose the child on you.", 'She thought she could raise it on her own.', "And that's what she did."]
#  > Processing time: 0.4353163242340088
#  > Real-time factor: 0.03660505884038034
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I never knew anything about it.']
#  > Processing time: 0.08224225044250488
#  > Real-time factor: 0.03558558913377616
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Me neither, at least not until recently.']
#  > Processing time: 0.08660030364990234
#  > Real-time factor: 0.02731655835832494
# Neutral
# enter there
#  > Text splitted to sentences.
# ['When did you find out?']
#  > Processing time: 0.08030867576599121
#  > Real-time factor: 0.049741750017980514
# Neutral
# enter there
#  > Text splitted to sentences.
# ['A few years ago.', 'When I turned eighteen, my grandmother told me this story.', 'Your love story.']
#  > Processing time: 0.28104615211486816
#  > Real-time factor: 0.03661184690266591
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I do.', 'Curiously, after all the lies you told me, I have no doubt about that.']
#  > Processing time: 0.19647979736328125
#  > Real-time factor: 0.031159231385646947
# Angry
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Stay, please.']
#  > Processing time: 0.08174443244934082
#  > Real-time factor: 0.05063103189629116
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I'm here."]
#  > Processing time: 0.09902477264404297
#  > Real-time factor: 0.07892915835747352
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I can understand that at the time, she didn't tell me anything.", 'But what about after?']
#  > Processing time: 0.20305418968200684
#  > Real-time factor: 0.033625817730775734
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I'm telling you again.", "She didn't want to impose this fatherhood on you.", 'And after that, she had lost track of you.']
#  > Processing time: 0.24453520774841309
#  > Real-time factor: 0.02920531096093958
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Soon after she left, I moved out of this apartment.', "I couldn't bear to see that window every day that reminded me of her absence."]
#  > Processing time: 0.2195572853088379
#  > Real-time factor: 0.024460580745047873
# Neutral
# enter there
#  > Text splitted to sentences.
# ['She sent you a letter a long time ago.', 'The letter was returned to her with the mention “Does not reside at this address”.']
# ðə lɛtɚ wəz ɹɪtɚnd tə hɚ wɪθ ðə mɛnʃən “dʌz nɑt ɹɪzaɪd æt ðɪs ædɹɛs”.
#  [!] Character '“' not found in the vocabulary. Discarding it.
# ðə lɛtɚ wəz ɹɪtɚnd tə hɚ wɪθ ðə mɛnʃən “dʌz nɑt ɹɪzaɪd æt ðɪs ædɹɛs”.
#  [!] Character '”' not found in the vocabulary. Discarding it.
#  > Processing time: 0.22934603691101074
#  > Real-time factor: 0.030338597342866834
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I came back to live here a few years ago.', 'To write this book, precisely.', 'As a way to exorcise the past.']
#  > Processing time: 0.2650105953216553
#  > Real-time factor: 0.029445918461473528
# Neutral
# enter there
#  > Text splitted to sentences.
# ['But her ghost has never stopped haunting you.']
#  > Processing time: 0.08303332328796387
#  > Real-time factor: 0.02871525687734635
# Neutral
# enter there
#  > Text splitted to sentences.
# ['I have known other women, of course.', 'But I will have lived my whole life in the memory of that first love.', 'I have never loved anyone else.']
#  > Processing time: 0.2636730670928955
#  > Real-time factor: 0.026998621412244343
# Neutral
# enter there
#  > Text splitted to sentences.
# ["She didn't know if you were married.", 'If you had founded a family on your side.']
#  > Processing time: 0.16937899589538574
#  > Real-time factor: 0.030835591640466117
# Neutral
# enter there
#  > Text splitted to sentences.
# ['That was not the case.']
#  > Processing time: 0.10061192512512207
#  > Real-time factor: 0.05125907922848756
# Neutral
# enter there
#  > Text splitted to sentences.
# ['She heard about you when you became a famous writer.']
#  > Processing time: 0.1120457649230957
#  > Real-time factor: 0.03293091699395207
# Neutral
# enter there
#  > Text splitted to sentences.
# ['It was also with the hope of winning her back that I did everything to succeed in the literary world.', 'And so that she could find me more easily thanks to my fame.', 'She could have contacted me at that time.']
#  > Processing time: 0.3363761901855469
#  > Real-time factor: 0.025887554425613267
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You would have thought she was coming back to you out of self- interest, now that you had become a successful author.', "That's what she feared, anyway."]
#  > Processing time: 0.20531439781188965
#  > Real-time factor: 0.024187801716918315
# Neutral
# enter there
#  > Text splitted to sentences.
# ['So I have a daughter.']
#  > Processing time: 0.0812678337097168
#  > Real-time factor: 0.04997645396305375
# Sleepy
# enter here
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['It was my grandmother who raised me.', 'And when I reached 18, she wanted me to know who my grandfather was.', 'But she did not dare to contact you again.']
#  > Processing time: 0.30196547508239746
#  > Real-time factor: 0.027663775200952537
# Neutral
# enter there
#  > Text splitted to sentences.
# ['So you decided to do it for her.', 'By coming to Paris.']
#  > Processing time: 0.16347670555114746
#  > Real-time factor: 0.0340011069782184
# Angry
# enter here
# Amused
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['And above all I read this manuscript.', 'I understood that you had never forgotten this woman.', 'My grandmother.']
#  > Processing time: 0.2562248706817627
#  > Real-time factor: 0.03170032318056416
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You did well to come.', 'and tell me the end of this story.']
#  > Processing time: 0.16249418258666992
#  > Real-time factor: 0.03801991432551009
# Neutral
# enter there
#  > Text splitted to sentences.
# ["It's not quite the end yet.", 'Are you okay?']
#  > Processing time: 0.1603689193725586
#  > Real-time factor: 0.04383348215198479
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I was already feeling down about my age, and now you're telling me I'm a grandfather."]
#  > Processing time: 0.08756303787231445
#  > Real-time factor: 0.015743354411974345
# Amused
# enter here
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["But here I'm .", 'I hardly knew my mother.', "I'm finding a grandfather."]
#  > Processing time: 0.26084232330322266
#  > Real-time factor: 0.0453708603814532
# Amused
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['The door was open.']
#  > Processing time: 0.08104491233825684
#  > Real-time factor: 0.04812150789149513
# Neutral
# enter there
#  > Text splitted to sentences.
# ['But I still need to find a real ending for this novel.']
#  > Processing time: 0.10541105270385742
#  > Real-time factor: 0.02654295761145688
# Neutral
# enter there
#  > Text splitted to sentences.
# ['For that, I can help you, as I told you.']
#  > Processing time: 0.10275506973266602
#  > Real-time factor: 0.02863687168358551
# Sleepy
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['There is one last thing, actually.']
#  > Processing time: 0.08235478401184082
#  > Real-time factor: 0.0318002764685677
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Go ahead.', "I'm already at a point where I can't be more surprised."]
#  > Processing time: 0.20220065116882324
#  > Real-time factor: 0.04067996677255979
# Neutral
# enter there
#  > Text splitted to sentences.
# ['My grandmother is still alive.']
#  > Processing time: 0.08170366287231445
#  > Real-time factor: 0.03058893246289279
# Neutral
# enter there
#  > Text splitted to sentences.
# ['And where does she live now?']
#  > Processing time: 0.0805063247680664
#  > Real-time factor: 0.03726831670171029
# Neutral
# enter there
#  > Text splitted to sentences.
# ['In New York.']
#  > Processing time: 0.08002686500549316
#  > Real-time factor: 0.0564705700643601
# Amused
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['You can do it yourself.']
#  > Processing time: 0.09901595115661621
#  > Real-time factor: 0.048440311568232766
# Neutral
# enter there
#  > Text splitted to sentences.
# ['Are you taking me back to America with you?']
#  > Processing time: 0.09156513214111328
#  > Real-time factor: 0.03009496726257375
# Neutral
# enter there
#  > Text splitted to sentences.
# ['My grandmother came with me.', "She's in the apartment across the courtyard."]
#  > Processing time: 0.1830611228942871
#  > Real-time factor: 0.03277229280185625
# Neutral
# enter there
#  > Text splitted to sentences.
# ["Now I'm really starting to get scared."]
#  > Processing time: 0.08687281608581543
#  > Real-time factor: 0.028995301445450324
# Amused
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ["But she didn't want to know about the author's life."]
#  > Processing time: 0.1018366813659668
#  > Real-time factor: 0.02972753156269286
# Neutral
# enter there
#  > Text splitted to sentences.
# ["You said it didn't matter."]
#  > Processing time: 0.08214449882507324
#  > Real-time factor: 0.04286459198913444
# Neutral
# enter there
#  > Text splitted to sentences.
# ["She's the one that is missing in this novel."]
#  > Processing time: 0.08188939094543457
#  > Real-time factor: 0.02671096257909515
# Sleepy
# enter here
# Amused
# enter here
# Neutral
# enter there
#  > Text splitted to sentences.
# ['So?', 'should I tell her to come over?']
#  > Processing time: 0.19849872589111328
#  > Real-time factor: 0.059964063265824305
# Neutral
# enter there
#  > Text splitted to sentences.
# ['She crossed the Atlantic to find me. I can cross the hallway to go to her.']
#  > Processing time: 0.11055994033813477
#  > Real-time factor: 0.020744100446356974
# Neutral
# enter there
#  > Text splitted to sentences.
# ["I'll let you go alone.", 'You will see.', 'Almost nothing has changed behind the window across the courtyard.', 'And the door is still open.']
#  > Processing time: 0.34332966804504395
#  > Real-time factor: 0.03536257090990853

# %%
vc = TTS(model_name="voice_conversion_models/multilingual/vctk/freevc24", progress_bar=False).to("cuda")
# Out:
#  > voice_conversion_models/multilingual/vctk/freevc24 is already downloaded.
#  > Using model: freevc
#  > Loading pretrained speaker encoder model ...
# Loaded the voice encoder model on cuda in 0.07 seconds.

# %%
char_dir = "character"
for file in os.listdir(final_dataset_path):
    name = file.split("_")[0]
    vc.voice_conversion_to_file(source_wav=os.path.join(final_dataset_path,file), target_wav=os.path.join(char_dir, dico[name]), file_path=os.path.join(final_dataset_path,file))
